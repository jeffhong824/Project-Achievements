# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from io import StringIO
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC,SVC
from sklearn.metrics import classification_report,make_scorer,f1_score
from itertools import product
from sklearn.model_selection import KFold,StratifiedKFold
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 細節 :
#
# * 調參過程中 tfidf fit時 用全部可用train fit 而不是用 skfold過的 部分train label True 當作 fit

# %%
def df_(df):
    df  = df [pd.notnull(df ['class'])]
    col = ['tweet', 'class']
    df = df[col]
    df.columns = ['tweet', 'label']
    label = df.label
    return df , label

# %%
def ML_method_one(tfidf_parameters,ML_model,ML_model_parameters,cv_times,train,train_label):

    tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2,max_df=15, norm='l2', encoding='utf-8', ngram_range=(1, 3), stop_words='english',max_features =None)
    kf = StratifiedKFold( n_splits = cv_times )
    kf.get_n_splits(train,train_label)
    
    tunelist_tfidf = [ dict( zip( tfidf_parameters , v ) ) for v in product ( *tfidf_parameters.values() ) ]
    tunelist_ML_model = [ dict( zip( ML_model_parameters , v ) ) for v in product ( *ML_model_parameters.values() ) ]
    
    tfidf_parameter_best_scores = []
    ML_model_best_scores_parameter = []
    
    for tfidf_parameter in tunelist_tfidf :

        tfidf.set_params( **tfidf_parameter )
        ML_model_parameter_scores = []

        for ML_model_parameter in tunelist_ML_model :

            ML_model.set_params( **ML_model_parameter )
            cv_scores_just_care_label_1_F1 = []
            
            num = 1
            
            print( 'tfidf para : ' , tfidf_parameter )
            print( 'Model para : ' , ML_model_parameter)
            
            for train_index , test_index in kf.split(train,train_label):

                cv_train , cv_test = train.loc[train_index], train.loc[test_index]
                cv_train_label , cv_test_label = train_label[train_index], train_label[test_index]
                
                tfidf.fit(train.loc[np.where(train_label.values==1)[0]].tweet.apply(lambda x: np.str_(x)) ) 

                cv_train = tfidf.transform( cv_train.tweet.apply( lambda x: np.str_(x) ) ) 
                cv_test = tfidf.transform( cv_test.tweet.apply( lambda x: np.str_(x) ) )

                ML_model.fit(cv_train,cv_train_label,)
                cv_pred = ML_model.predict(cv_test)

                cv_scores_just_care_label_1_F1.append( float(classification_report(cv_test_label,cv_pred,digits=5).split()[12]) )
                now_score = float(classification_report(cv_test_label,cv_pred,digits=5).split()[12])
                print('\t第'+str(num)+'次kfold，label 1 - F1 score : ' + str(now_score))

                num+=1
                
            ML_model_parameter_scores.append(np.mean(cv_scores_just_care_label_1_F1))
            print('\t此參數kfold平均為'+str(np.mean(cv_scores_just_care_label_1_F1)))
        tfidf_parameter_best_scores.append( np.max( np.array(ML_model_parameter_scores) ) )
        ML_model_best_scores_parameter.append(tunelist_ML_model[ np.argmax(np.array(ML_model_parameter_scores))] )
    
    print('調參完成 最佳參數為 : ' , tunelist_tfidf[np.argmax(np.array(tfidf_parameter_best_scores))] ,  ML_model_best_scores_parameter[np.argmax(np.array(tfidf_parameter_best_scores))] )
    return tunelist_tfidf[np.argmax(np.array(tfidf_parameter_best_scores))] , ML_model_best_scores_parameter[np.argmax(np.array(tfidf_parameter_best_scores))]

# %%
path = 'C:/Users/jeffh/Desktop/Sdata/'

# %% [markdown]
# # 第一種 單個DT 單純2020資料
#
# ## TF-IDF
#
# fit :
#
# * 2020 train label - True
#
# transform :
#
# * 2020 train label - True & False

# %% [markdown]
# ### Train data

# %%
trainpath=path+'task1_training.xlsx'

# %%
train_ = pd.read_excel(trainpath)

# %%
train , train_label = df_(train_)

# %% [markdown]
# ### Test data

# %%
testpath = path+'task1_validation.xlsx'

# %%
test_ = pd.read_excel(testpath)

# %%
test , test_label = df_(test_)

# %%
print('train - label 1   : ' , len(train[train.label==1]))
print('train - label 0   : ' , len(train[train.label==0]))
print('dev   - label 1   : ' , len(test[test.label==1]))
print('dev   - label 0   : ' , len(test[test.label==0]))
# Out:
# train - label 1   :  146
# train - label 0   :  55273
# dev   - label 1   :  35
# dev   - label 0   :  13818

# %% [markdown]
# ### train & finetune Model

# %%
tfidf_parameters = { 
'min_df': [2,3],
'max_df' : [5,10,15,20],
'ngram_range' : [(1,2),(1,3),(1,4)]
}

ML_model_parameters = { 
'min_samples_split': [0.1,0.01,0.001,0.0001],
'min_samples_leaf' : [1,2], 
}

ML_model = DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split = 0.1,max_features=None,random_state=7)
#ML_model = DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=0.1,max_features=None,random_state=7)

# %%
tfidf_want_parameters , model_want_parameters = ML_method_one( tfidf_parameters , ML_model , ML_model_parameters , 4  , train , train_label  )
# Out:
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52
# 	第2次kfold，label 1 - F1 score : 0.41667
# 	第3次kfold，label 1 - F1 score : 0.31111
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.43939500000000004
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05128
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17809750000000002
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5098
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.31111
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4288325
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05128
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17809750000000002
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5098
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.29787
# 	第4次kfold，label 1 - F1 score : 0.46429
# 	此參數kfold平均為0.414145
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.04878
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17747250000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48148
# 	第2次kfold，label 1 - F1 score : 0.36364
# 	第3次kfold，label 1 - F1 score : 0.32
# 	第4次kfold，label 1 - F1 score : 0.44068
# 	此參數kfold平均為0.40145000000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.18605
# 	第2次kfold，label 1 - F1 score : 0.29167
# 	第3次kfold，label 1 - F1 score : 0.08889
# 	第4次kfold，label 1 - F1 score : 0.20833
# 	此參數kfold平均為0.193735
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52
# 	第2次kfold，label 1 - F1 score : 0.41667
# 	第3次kfold，label 1 - F1 score : 0.31111
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.43939500000000004
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05128
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17809750000000002
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5098
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.31111
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4288325
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05128
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17809750000000002
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5098
# 	第2次kfold，label 1 - F1 score : 0.37736
# 	第3次kfold，label 1 - F1 score : 0.29787
# 	第4次kfold，label 1 - F1 score : 0.47273
# 	此參數kfold平均為0.41444000000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.04878
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17747250000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.49057
# 	第2次kfold，label 1 - F1 score : 0.35714
# 	第3次kfold，label 1 - F1 score : 0.31373
# 	第4次kfold，label 1 - F1 score : 0.44068
# 	此參數kfold平均為0.40053
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.18605
# 	第2次kfold，label 1 - F1 score : 0.29167
# 	第3次kfold，label 1 - F1 score : 0.08889
# 	第4次kfold，label 1 - F1 score : 0.20833
# 	此參數kfold平均為0.193735
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52
# 	第2次kfold，label 1 - F1 score : 0.41667
# 	第3次kfold，label 1 - F1 score : 0.31111
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.43939500000000004
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05128
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17809750000000002
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5098
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.31111
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4288325
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05128
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17809750000000002
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5098
# 	第2次kfold，label 1 - F1 score : 0.37736
# 	第3次kfold，label 1 - F1 score : 0.29787
# 	第4次kfold，label 1 - F1 score : 0.47273
# 	此參數kfold平均為0.41444000000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.04878
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.17747250000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.49057
# 	第2次kfold，label 1 - F1 score : 0.35714
# 	第3次kfold，label 1 - F1 score : 0.31373
# 	第4次kfold，label 1 - F1 score : 0.44068
# 	此參數kfold平均為0.40053
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.18605
# 	第2次kfold，label 1 - F1 score : 0.29167
# 	第3次kfold，label 1 - F1 score : 0.08889
# 	第4次kfold，label 1 - F1 score : 0.20833
# 	此參數kfold平均為0.193735
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65574
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.73333
# 	此參數kfold平均為0.652825
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65574
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.73333
# 	此參數kfold平均為0.6502975
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65574
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.70968
# 	此參數kfold平均為0.6396025
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63492
# 	第2次kfold，label 1 - F1 score : 0.51724
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.67692
# 	此參數kfold平均為0.6239375
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.43636
# 	第2次kfold，label 1 - F1 score : 0.50909
# 	第3次kfold，label 1 - F1 score : 0.50847
# 	第4次kfold，label 1 - F1 score : 0.58182
# 	此參數kfold平均為0.508935
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.73333
# 	此參數kfold平均為0.6472225
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.73333
# 	此參數kfold平均為0.644695
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.70968
# 	此參數kfold平均為0.634
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.51724
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6134375
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.43636
# 	第2次kfold，label 1 - F1 score : 0.50909
# 	第3次kfold，label 1 - F1 score : 0.50847
# 	第4次kfold，label 1 - F1 score : 0.58182
# 	此參數kfold平均為0.508935
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.73333
# 	此參數kfold平均為0.6472225
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.73333
# 	此參數kfold平均為0.644695
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.70968
# 	此參數kfold平均為0.634
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.51179
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.51724
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6134375
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.43636
# 	第2次kfold，label 1 - F1 score : 0.50909
# 	第3次kfold，label 1 - F1 score : 0.50847
# 	第4次kfold，label 1 - F1 score : 0.58182
# 	此參數kfold平均為0.508935
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7090000000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7062775000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71642
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.68852
# 	第4次kfold，label 1 - F1 score : 0.70769
# 	此參數kfold平均為0.6807
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70588
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69565
# 	此參數kfold平均為0.66705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.56667
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.60714
# 	此參數kfold平均為0.60041
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7137800000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7110575000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72464
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.67742
# 	第4次kfold，label 1 - F1 score : 0.71875
# 	此參數kfold平均為0.682745
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70423
# 	第2次kfold，label 1 - F1 score : 0.59016
# 	第3次kfold，label 1 - F1 score : 0.69697
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6645074999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.56667
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.60714
# 	此參數kfold平均為0.60041
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7137800000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7110575000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72464
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.67742
# 	第4次kfold，label 1 - F1 score : 0.71875
# 	此參數kfold平均為0.682745
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70423
# 	第2次kfold，label 1 - F1 score : 0.59016
# 	第3次kfold，label 1 - F1 score : 0.69697
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6645074999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.56667
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.60714
# 	此參數kfold平均為0.60041
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7090000000000001
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7062775000000001
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71642
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.68852
# 	第4次kfold，label 1 - F1 score : 0.70769
# 	此參數kfold平均為0.6807
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70588
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69565
# 	此參數kfold平均為0.66705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.56667
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.60714
# 	此參數kfold平均為0.60041
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7137800000000001
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7110575000000001
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72464
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.67742
# 	第4次kfold，label 1 - F1 score : 0.71875
# 	此參數kfold平均為0.682745
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70423
# 	第2次kfold，label 1 - F1 score : 0.59016
# 	第3次kfold，label 1 - F1 score : 0.69697
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6645074999999999
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.56667
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.60714
# 	此參數kfold平均為0.60041
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7137800000000001
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7110575000000001
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72464
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.67742
# 	第4次kfold，label 1 - F1 score : 0.71875
# 	此參數kfold平均為0.682745
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.587705
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70423
# 	第2次kfold，label 1 - F1 score : 0.59016
# 	第3次kfold，label 1 - F1 score : 0.69697
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6645074999999999
# tfidf para :  {'min_df': 2, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.56667
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.60714
# 	此參數kfold平均為0.60041
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.3913
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.3152925
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.3913
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.3152925
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.36735
# 	第2次kfold，label 1 - F1 score : 0.30435
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.34043
# 	此參數kfold平均為0.3018125
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.36
# 	第2次kfold，label 1 - F1 score : 0.33333
# 	第3次kfold，label 1 - F1 score : 0.19048
# 	第4次kfold，label 1 - F1 score : 0.33333
# 	此參數kfold平均為0.304285
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.14286
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.1
# 	第4次kfold，label 1 - F1 score : 0.18605
# 	此參數kfold平均為0.18500499999999998
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.3913
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.3152925
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.3913
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.3152925
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.36735
# 	第2次kfold，label 1 - F1 score : 0.30435
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.34043
# 	此參數kfold平均為0.3018125
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.36
# 	第2次kfold，label 1 - F1 score : 0.33333
# 	第3次kfold，label 1 - F1 score : 0.19048
# 	第4次kfold，label 1 - F1 score : 0.33333
# 	此參數kfold平均為0.304285
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.14286
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.1
# 	第4次kfold，label 1 - F1 score : 0.18605
# 	此參數kfold平均為0.18500499999999998
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.3913
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.3152925
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.3913
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.3152925
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.36735
# 	第2次kfold，label 1 - F1 score : 0.30435
# 	第3次kfold，label 1 - F1 score : 0.19512
# 	第4次kfold，label 1 - F1 score : 0.34043
# 	此參數kfold平均為0.3018125
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.15
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.05263
# 	第4次kfold，label 1 - F1 score : 0.2
# 	此參數kfold平均為0.178435
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.36
# 	第2次kfold，label 1 - F1 score : 0.33333
# 	第3次kfold，label 1 - F1 score : 0.19048
# 	第4次kfold，label 1 - F1 score : 0.33333
# 	此參數kfold平均為0.304285
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.14286
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.1
# 	第4次kfold，label 1 - F1 score : 0.18605
# 	此參數kfold平均為0.18500499999999998
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5614
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.65455
# 	第4次kfold，label 1 - F1 score : 0.64151
# 	此參數kfold平均為0.5964400000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.521405
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5614
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.65455
# 	第4次kfold，label 1 - F1 score : 0.64151
# 	此參數kfold平均為0.5964400000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.521405
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.53333
# 	第2次kfold，label 1 - F1 score : 0.48276
# 	第3次kfold，label 1 - F1 score : 0.58065
# 	第4次kfold，label 1 - F1 score : 0.59649
# 	此參數kfold平均為0.5483075
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.50909
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.5166025
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52459
# 	第2次kfold，label 1 - F1 score : 0.47619
# 	第3次kfold，label 1 - F1 score : 0.55385
# 	第4次kfold，label 1 - F1 score : 0.63636
# 	此參數kfold平均為0.5477475
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.40741
# 	第2次kfold，label 1 - F1 score : 0.51724
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.55738
# 	此參數kfold平均為0.5051224999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5614
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.65455
# 	第4次kfold，label 1 - F1 score : 0.64151
# 	此參數kfold平均為0.5964400000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.521405
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5614
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.65455
# 	第4次kfold，label 1 - F1 score : 0.64151
# 	此參數kfold平均為0.5964400000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.521405
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.53333
# 	第2次kfold，label 1 - F1 score : 0.48276
# 	第3次kfold，label 1 - F1 score : 0.58065
# 	第4次kfold，label 1 - F1 score : 0.59649
# 	此參數kfold平均為0.5483075
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.50909
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.5166025
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52459
# 	第2次kfold，label 1 - F1 score : 0.47619
# 	第3次kfold，label 1 - F1 score : 0.55385
# 	第4次kfold，label 1 - F1 score : 0.63636
# 	此參數kfold平均為0.5477475
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.40741
# 	第2次kfold，label 1 - F1 score : 0.51724
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.55738
# 	此參數kfold平均為0.5051224999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5614
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.65455
# 	第4次kfold，label 1 - F1 score : 0.64151
# 	此參數kfold平均為0.5964400000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.521405
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5614
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.65455
# 	第4次kfold，label 1 - F1 score : 0.64151
# 	此參數kfold平均為0.5964400000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.521405
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.53333
# 	第2次kfold，label 1 - F1 score : 0.48276
# 	第3次kfold，label 1 - F1 score : 0.58065
# 	第4次kfold，label 1 - F1 score : 0.59649
# 	此參數kfold平均為0.5483075
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.39216
# 	第2次kfold，label 1 - F1 score : 0.50909
# 	第3次kfold，label 1 - F1 score : 0.57692
# 	第4次kfold，label 1 - F1 score : 0.58824
# 	此參數kfold平均為0.5166025
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52459
# 	第2次kfold，label 1 - F1 score : 0.47619
# 	第3次kfold，label 1 - F1 score : 0.55385
# 	第4次kfold，label 1 - F1 score : 0.63636
# 	此參數kfold平均為0.5477475
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.40741
# 	第2次kfold，label 1 - F1 score : 0.51724
# 	第3次kfold，label 1 - F1 score : 0.53846
# 	第4次kfold，label 1 - F1 score : 0.55738
# 	此參數kfold平均為0.5051224999999999
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.62069
# 	此參數kfold平均為0.6225974999999999
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64706
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.60606
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.6176925
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54839
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.61818
# 	第4次kfold，label 1 - F1 score : 0.6129
# 	此參數kfold平均為0.6027625
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.62069
# 	此參數kfold平均為0.6225974999999999
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64706
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.60606
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.6176925
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54839
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.61818
# 	第4次kfold，label 1 - F1 score : 0.6129
# 	此參數kfold平均為0.6027625
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.62069
# 	此參數kfold平均為0.6225974999999999
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64706
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.60606
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.6176925
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54839
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.61818
# 	第4次kfold，label 1 - F1 score : 0.6129
# 	此參數kfold平均為0.6027625
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.62069
# 	此參數kfold平均為0.6225974999999999
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64706
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.60606
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.6176925
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54839
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.61818
# 	第4次kfold，label 1 - F1 score : 0.6129
# 	此參數kfold平均為0.6027625
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.62069
# 	此參數kfold平均為0.6225974999999999
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64706
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.60606
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.6176925
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54839
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.61818
# 	第4次kfold，label 1 - F1 score : 0.6129
# 	此參數kfold平均為0.6027625
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.67742
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.70175
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.663245
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.62069
# 	此參數kfold平均為0.6225974999999999
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.53571
# 	第2次kfold，label 1 - F1 score : 0.60714
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.61538
# 	此參數kfold平均為0.5969650000000001
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64706
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.60606
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.6176925
# tfidf para :  {'min_df': 3, 'max_df': 20, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54839
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.61818
# 	第4次kfold，label 1 - F1 score : 0.6129
# 	此參數kfold平均為0.6027625
# 調參完成 最佳參數為 :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)} {'min_samples_split': 0.1, 'min_samples_leaf': 1}

# %%
tfidf_want_parameters
# Out:
# {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}

# %%
model_want_parameters
# Out:
# {'min_samples_split': 0.1, 'min_samples_leaf': 1}

# %%
tfidf_want_parameters = {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}

# %%
model_want_parameters = {'min_samples_split': 0.1, 'min_samples_leaf': 1}

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2,max_df=15, norm='l2', encoding='utf-8', ngram_range=(1, 2), stop_words='english',max_features =None)
ML_model= DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=1e-07,min_samples_leaf= 1,max_features=None,random_state=7)

tfidf.set_params( **tfidf_want_parameters )
ML_model.set_params( **model_want_parameters )

tfidf.fit(train.loc[np.where(train_label.values==1)[0]].tweet.apply(lambda x: np.str_(x)) ) 
tfidf_train = tfidf.transform(train.tweet.apply(lambda x: np.str_(x))) 
tfidf_test = tfidf.transform(test.tweet.apply(lambda x: np.str_(x)))

ML_model.fit( tfidf_train , train_label )
pred = ML_model.predict( tfidf_test )

print( classification_report(test_label,pred,digits=5).split()[12])  
print( classification_report(test_label,pred,digits=5) )
# Out:
# 0.76667
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99986   0.99949     13818
#            1    0.92000   0.65714   0.76667        35
#
#    micro avg    0.99899   0.99899   0.99899     13853
#    macro avg    0.95957   0.82850   0.88308     13853
# weighted avg    0.99893   0.99899   0.99891     13853

# %% [raw]
# 結論 : 在基礎model 僅fit label True 即可做到在val 0.76667 F1 score

# %%
train_words = tfidf.get_feature_names()

print("feature:",len(train_words))
print('extract_word:', train_words)
# Out:
# feature: 222
# extract_word: ['1st', 'acetaminophen', 'adderall', 'af', 'amp drink', 'amp im', 'antibiotics', 'arm', 'asleep', 'baby', 'bad', 'bc', 'bed', 'best', 'best friend', 'better', 'birth', 'birth control', 'botox', 'bottle', 'bottle tums', 'bring', 'button', 'canadiankelli', 'castor', 'castor oil', 'cause', 'chloemugg', 'contractions', 'control', 'daily', 'day', 'diabetics', 'diclectin', 'did', 'didnt', 'die', 'doctor', 'does', 'dont', 'drink', 'eat', 'effects', 'end', 'entonox', 'epidural', 'extra', 'fact', 'faster', 'fat', 'feel', 'feel like', 'feel sick', 'feeling', 'finally', 'fine', 'flu', 'friend', 'fucking', 'gain', 'gaviscon', 'getting', 'getting nexplanon', 'giving', 'gmo', 'gmo insulin', 'god', 'goes', 'going', 'gonna', 'good', 'got', 'great', 'hair', 'happy', 'hard', 'hate', 'havent', 'having', 'head', 'headache', 'help', 'helps', 'hey', 'high', 'home', 'hope', 'hour', 'hours', 'http', 'https', 'hurt', 'husband', 'ibuprofen', 'ill', 'im getting', 'im getting nexplanon', 'im just', 'imma', 'infection', 'insulin', 'ive', 'just want', 'kicking', 'know', 'like', 'little', 'lol', 'longer', 'look', 'love', 'lungs', 'make', 'make feel', 'makes', 'makes feel', 'massive', 'medicine', 'meds', 'meds make', 'morphine', 'muscle', 'muscle relaxer', 'muscle relaxers', 'nasal', 'nasal spray', 'need', 'need tums', 'needs', 'new', 'nexplanon', 'night', 'noct_harley', 'nurse', 'nyquil', 'oh', 'oil', 'orange', 'otc', 'pain', 'pain meds', 'painkillers', 'people', 'person', 'pill', 'pills', 'pregnancy', 'pregnant', 'prenatal', 'prenatal vitamins', 'prenatals', 'properly', 'real', 'really', 'relaxer', 'relaxers', 'reminds', 'ridiculous', 'room', 'room amp', 'run', 'said', 'set', 'shit', 'shot', 'shouldnt', 'sick', 'sleep', 'sleeping', 'sleepy', 'son', 'soon', 'sore', 'sounds', 'spray', 'start', 'steroid', 'steroids', 'stop', 'sucked', 'sudafed', 'sure', 'swear', 'switching', 'taking', 'thank', 'thank god', 'thanks', 'thing', 'think', 'think im', 'throat', 'time', 'times', 'today', 'told', 'tonight', 'took', 'tried', 'try', 'trying', 'tums', 'twice', 'tylenol', 'tylenol amp', 'tylenol3', 'type', 'vitamins', 'wakes', 'wanna', 'want', 'water', 'wine', 'wonderful', 'wont', 'work', 'working', 'world', 'worst', 'wouldnt', 'yall', 'zantac']

# %% [markdown]
# # 第一種 單個DT 單純2020資料 但看過dev data
#
# ## TF-IDF
#
# fit :
#
# * 2020 train label - True
# * 2020 val label - True
#
# transform :
#
# * 2020 train label - True & False
# * 2020 val label - True & False

# %% [markdown]
# ### Train data

# %%
trainpath=path+'task1_all.xlsx'

# %%
train_ = pd.read_excel(trainpath)

# %%
train , train_label = df_(train_)

# %% [markdown]
# ### Test data

# %%
testpath = path+'task1_validation.xlsx'

# %%
test_ = pd.read_excel(testpath)

# %%
test , test_label = df_(test_)

# %%
print('train - label 1   : ' , len(train[train.label==1]))
print('train - label 0   : ' , len(train[train.label==0]))
print('dev   - label 1   : ' , len(test[test.label==1]))
print('dev   - label 0   : ' , len(test[test.label==0]))
# Out:
# train - label 1   :  181
# train - label 0   :  69091
# dev   - label 1   :  35
# dev   - label 0   :  13818

# %% [markdown]
# ### train & finetune Model

# %%
tfidf_parameters = { 
'min_df': [2,3],
'max_df' : [5,10,15],
'ngram_range' : [(1,2),(1,3),(1,4)]
}

ML_model_parameters = { 
'min_samples_split': [0.1,0.01,0.001,0.0001],
'min_samples_leaf' : [1,2], 
}
ML_model= DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=0.1,max_features=None,random_state=7)

# %%
tfidf_want_parameters , model_want_parameters = ML_method_one( tfidf_parameters , ML_model , ML_model_parameters , 4  , train , train_label  )
# Out:
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.55385
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.59375
# 	此參數kfold平均為0.52316
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.23077
# 	第2次kfold，label 1 - F1 score : 0.2963
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.29540500000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.55385
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.59375
# 	此參數kfold平均為0.52316
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.23077
# 	第2次kfold，label 1 - F1 score : 0.2963
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.29540500000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52941
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.50746
# 	第4次kfold，label 1 - F1 score : 0.58462
# 	此參數kfold平均為0.50882
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.23077
# 	第2次kfold，label 1 - F1 score : 0.2963
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.29540500000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.4
# 	第3次kfold，label 1 - F1 score : 0.44737
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.4765475
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.24561
# 	第2次kfold，label 1 - F1 score : 0.29091
# 	第3次kfold，label 1 - F1 score : 0.29508
# 	第4次kfold，label 1 - F1 score : 0.35714
# 	此參數kfold平均為0.29718500000000003
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48
# 	第2次kfold，label 1 - F1 score : 0.4127
# 	第3次kfold，label 1 - F1 score : 0.44156
# 	第4次kfold，label 1 - F1 score : 0.53731
# 	此參數kfold平均為0.4678925
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.24561
# 	第2次kfold，label 1 - F1 score : 0.31579
# 	第3次kfold，label 1 - F1 score : 0.31034
# 	第4次kfold，label 1 - F1 score : 0.32727
# 	此參數kfold平均為0.2997525
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52941
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.58462
# 	此參數kfold平均為0.5147675
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.22642
# 	第2次kfold，label 1 - F1 score : 0.2963
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.2943175
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52941
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.58462
# 	此參數kfold平均為0.5147675
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.22642
# 	第2次kfold，label 1 - F1 score : 0.2963
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.2943175
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.50704
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.57576
# 	此參數kfold平均為0.4991475
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.22642
# 	第2次kfold，label 1 - F1 score : 0.2963
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.36364
# 	此參數kfold平均為0.2943175
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47368
# 	第2次kfold，label 1 - F1 score : 0.42623
# 	第3次kfold，label 1 - F1 score : 0.44737
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.476525
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.24138
# 	第2次kfold，label 1 - F1 score : 0.29091
# 	第3次kfold，label 1 - F1 score : 0.29508
# 	第4次kfold，label 1 - F1 score : 0.38596
# 	此參數kfold平均為0.3033325
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47368
# 	第2次kfold，label 1 - F1 score : 0.42623
# 	第3次kfold，label 1 - F1 score : 0.44737
# 	第4次kfold，label 1 - F1 score : 0.53731
# 	此參數kfold平均為0.4711475
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.21429
# 	第2次kfold，label 1 - F1 score : 0.31579
# 	第3次kfold，label 1 - F1 score : 0.29032
# 	第4次kfold，label 1 - F1 score : 0.2963
# 	此參數kfold平均為0.279175
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52941
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.60606
# 	此參數kfold平均為0.5201275000000001
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.22642
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.38596
# 	此參數kfold平均為0.30764
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52941
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.60606
# 	此參數kfold平均為0.5201275000000001
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.22642
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.38596
# 	此參數kfold平均為0.30764
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.50704
# 	第2次kfold，label 1 - F1 score : 0.41379
# 	第3次kfold，label 1 - F1 score : 0.50746
# 	第4次kfold，label 1 - F1 score : 0.59701
# 	此參數kfold平均為0.506325
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.22642
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.38596
# 	此參數kfold平均為0.30764
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48
# 	第2次kfold，label 1 - F1 score : 0.3871
# 	第3次kfold，label 1 - F1 score : 0.44156
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.4700225
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.24138
# 	第2次kfold，label 1 - F1 score : 0.32143
# 	第3次kfold，label 1 - F1 score : 0.29508
# 	第4次kfold，label 1 - F1 score : 0.37931
# 	此參數kfold平均為0.3093
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46753
# 	第2次kfold，label 1 - F1 score : 0.3871
# 	第3次kfold，label 1 - F1 score : 0.44156
# 	第4次kfold，label 1 - F1 score : 0.53521
# 	此參數kfold平均為0.45785
# tfidf para :  {'min_df': 2, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.24138
# 	第2次kfold，label 1 - F1 score : 0.31579
# 	第3次kfold，label 1 - F1 score : 0.31034
# 	第4次kfold，label 1 - F1 score : 0.35088
# 	此參數kfold平均為0.3045975
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64
# 	第2次kfold，label 1 - F1 score : 0.57576
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.67606
# 	此參數kfold平均為0.6396225
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.53125
# 	此參數kfold平均為0.5097975
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63158
# 	第2次kfold，label 1 - F1 score : 0.57576
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.67606
# 	此參數kfold平均為0.6375175000000001
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.53125
# 	此參數kfold平均為0.5097975
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.6
# 	第2次kfold，label 1 - F1 score : 0.55882
# 	第3次kfold，label 1 - F1 score : 0.64865
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.618535
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.53125
# 	此參數kfold平均為0.5097975
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.57471
# 	第2次kfold，label 1 - F1 score : 0.57143
# 	第3次kfold，label 1 - F1 score : 0.65789
# 	第4次kfold，label 1 - F1 score : 0.63158
# 	此參數kfold平均為0.6089025
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50704
# 	第2次kfold，label 1 - F1 score : 0.51613
# 	第3次kfold，label 1 - F1 score : 0.53731
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5285825
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5814
# 	第2次kfold，label 1 - F1 score : 0.52941
# 	第3次kfold，label 1 - F1 score : 0.64103
# 	第4次kfold，label 1 - F1 score : 0.65789
# 	此參數kfold平均為0.6024325
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50704
# 	第2次kfold，label 1 - F1 score : 0.51613
# 	第3次kfold，label 1 - F1 score : 0.51515
# 	第4次kfold，label 1 - F1 score : 0.53125
# 	此參數kfold平均為0.5173924999999999
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64
# 	第2次kfold，label 1 - F1 score : 0.57576
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.65714
# 	此參數kfold平均為0.6348925
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.50397
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63158
# 	第2次kfold，label 1 - F1 score : 0.57576
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.65714
# 	此參數kfold平均為0.6327875000000001
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.50397
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.6
# 	第2次kfold，label 1 - F1 score : 0.55882
# 	第3次kfold，label 1 - F1 score : 0.64865
# 	第4次kfold，label 1 - F1 score : 0.64789
# 	此參數kfold平均為0.6138399999999999
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.50397
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5814
# 	第2次kfold，label 1 - F1 score : 0.52174
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.62162
# 	此參數kfold平均為0.60002
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50704
# 	第2次kfold，label 1 - F1 score : 0.51613
# 	第3次kfold，label 1 - F1 score : 0.53731
# 	第4次kfold，label 1 - F1 score : 0.53125
# 	此參數kfold平均為0.5229325
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5814
# 	第2次kfold，label 1 - F1 score : 0.60274
# 	第3次kfold，label 1 - F1 score : 0.63158
# 	第4次kfold，label 1 - F1 score : 0.61333
# 	此參數kfold平均為0.6072625
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50704
# 	第2次kfold，label 1 - F1 score : 0.51613
# 	第3次kfold，label 1 - F1 score : 0.51515
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.5115649999999999
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61333
# 	第2次kfold，label 1 - F1 score : 0.57576
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69444
# 	此參數kfold平均為0.6375500000000001
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.49275
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.52308
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.5079275
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60526
# 	第2次kfold，label 1 - F1 score : 0.57576
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69444
# 	此參數kfold平均為0.6355325000000001
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.49275
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.52308
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.5079275
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.58228
# 	第2次kfold，label 1 - F1 score : 0.55882
# 	第3次kfold，label 1 - F1 score : 0.64
# 	第4次kfold，label 1 - F1 score : 0.68493
# 	此參數kfold平均為0.6165075
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.49275
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.52308
# 	第4次kfold，label 1 - F1 score : 0.50794
# 	此參數kfold平均為0.5079275
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.57143
# 	第2次kfold，label 1 - F1 score : 0.53521
# 	第3次kfold，label 1 - F1 score : 0.64935
# 	第4次kfold，label 1 - F1 score : 0.65789
# 	此參數kfold平均為0.6034700000000001
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.51613
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.52308
# 	此參數kfold平均為0.521165
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.55814
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.63158
# 	第4次kfold，label 1 - F1 score : 0.62338
# 	此參數kfold平均為0.603275
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.48387
# 	第3次kfold，label 1 - F1 score : 0.52308
# 	第4次kfold，label 1 - F1 score : 0.5
# 	此參數kfold平均為0.5017375
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75294
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.75325
# 	第4次kfold，label 1 - F1 score : 0.83951
# 	此參數kfold平均為0.7645074999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.65823
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.653985
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75294
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.75325
# 	第4次kfold，label 1 - F1 score : 0.83951
# 	此參數kfold平均為0.7645074999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.65823
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.653985
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73563
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.73418
# 	第4次kfold，label 1 - F1 score : 0.81928
# 	此參數kfold平均為0.7503550000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.65823
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.653985
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.7191
# 	第2次kfold，label 1 - F1 score : 0.7027
# 	第3次kfold，label 1 - F1 score : 0.75294
# 	第4次kfold，label 1 - F1 score : 0.80488
# 	此參數kfold平均為0.7449049999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.63291
# 	第2次kfold，label 1 - F1 score : 0.64706
# 	第3次kfold，label 1 - F1 score : 0.64865
# 	第4次kfold，label 1 - F1 score : 0.72222
# 	此參數kfold平均為0.66271
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71111
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.73563
# 	第4次kfold，label 1 - F1 score : 0.81481
# 	此參數kfold平均為0.74347
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.63291
# 	第2次kfold，label 1 - F1 score : 0.64706
# 	第3次kfold，label 1 - F1 score : 0.63889
# 	第4次kfold，label 1 - F1 score : 0.68571
# 	此參數kfold平均為0.6511425
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.77108
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.75325
# 	第4次kfold，label 1 - F1 score : 0.83951
# 	此參數kfold平均為0.7690425000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6582575
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.77108
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.75325
# 	第4次kfold，label 1 - F1 score : 0.83951
# 	此參數kfold平均為0.7690425000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6582575
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75294
# 	第2次kfold，label 1 - F1 score : 0.69333
# 	第3次kfold，label 1 - F1 score : 0.725
# 	第4次kfold，label 1 - F1 score : 0.81928
# 	此參數kfold平均為0.7476375000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6582575
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.74419
# 	第2次kfold，label 1 - F1 score : 0.68421
# 	第3次kfold，label 1 - F1 score : 0.72941
# 	第4次kfold，label 1 - F1 score : 0.80488
# 	此參數kfold平均為0.7406725000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.64935
# 	第2次kfold，label 1 - F1 score : 0.66667
# 	第3次kfold，label 1 - F1 score : 0.64865
# 	第4次kfold，label 1 - F1 score : 0.72222
# 	此參數kfold平均為0.6717225
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.74419
# 	第2次kfold，label 1 - F1 score : 0.68421
# 	第3次kfold，label 1 - F1 score : 0.73563
# 	第4次kfold，label 1 - F1 score : 0.79518
# 	此參數kfold平均為0.7398024999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.64935
# 	第2次kfold，label 1 - F1 score : 0.66667
# 	第3次kfold，label 1 - F1 score : 0.59459
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.64432
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.77108
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.75325
# 	第4次kfold，label 1 - F1 score : 0.83951
# 	此參數kfold平均為0.7690425000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6629875000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.77108
# 	第2次kfold，label 1 - F1 score : 0.71233
# 	第3次kfold，label 1 - F1 score : 0.75325
# 	第4次kfold，label 1 - F1 score : 0.83951
# 	此參數kfold平均為0.7690425000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6629875000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75294
# 	第2次kfold，label 1 - F1 score : 0.7027
# 	第3次kfold，label 1 - F1 score : 0.73418
# 	第4次kfold，label 1 - F1 score : 0.81928
# 	此參數kfold平均為0.752275
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.58824
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6629875000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.69565
# 	第2次kfold，label 1 - F1 score : 0.68421
# 	第3次kfold，label 1 - F1 score : 0.72289
# 	第4次kfold，label 1 - F1 score : 0.79518
# 	此參數kfold平均為0.7244824999999999
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.64935
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.65753
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.6738175
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71111
# 	第2次kfold，label 1 - F1 score : 0.7013
# 	第3次kfold，label 1 - F1 score : 0.74419
# 	第4次kfold，label 1 - F1 score : 0.80488
# 	此參數kfold平均為0.74037
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.64935
# 	第2次kfold，label 1 - F1 score : 0.65714
# 	第3次kfold，label 1 - F1 score : 0.63889
# 	第4次kfold，label 1 - F1 score : 0.65714
# 	此參數kfold平均為0.6506299999999999
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32143
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.35714
# 	第4次kfold，label 1 - F1 score : 0.46667
# 	此參數kfold平均為0.3681275
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32143
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.35714
# 	第4次kfold，label 1 - F1 score : 0.44444
# 	此參數kfold平均為0.36257
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31034
# 	第2次kfold，label 1 - F1 score : 0.31579
# 	第3次kfold，label 1 - F1 score : 0.34483
# 	第4次kfold，label 1 - F1 score : 0.43077
# 	此參數kfold平均為0.35043250000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32787
# 	第2次kfold，label 1 - F1 score : 0.34483
# 	第3次kfold，label 1 - F1 score : 0.35484
# 	第4次kfold，label 1 - F1 score : 0.49275
# 	此參數kfold平均為0.38007250000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.21818
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.44068
# 	此參數kfold平均為0.31926
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31746
# 	第2次kfold，label 1 - F1 score : 0.33898
# 	第3次kfold，label 1 - F1 score : 0.35821
# 	第4次kfold，label 1 - F1 score : 0.47059
# 	此參數kfold平均為0.37131000000000003
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.18868
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.41379
# 	此參數kfold平均為0.3051625
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32143
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.35714
# 	第4次kfold，label 1 - F1 score : 0.46667
# 	此參數kfold平均為0.3681275
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32143
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.35714
# 	第4次kfold，label 1 - F1 score : 0.44444
# 	此參數kfold平均為0.36257
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31034
# 	第2次kfold，label 1 - F1 score : 0.31579
# 	第3次kfold，label 1 - F1 score : 0.34483
# 	第4次kfold，label 1 - F1 score : 0.43077
# 	此參數kfold平均為0.35043250000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32787
# 	第2次kfold，label 1 - F1 score : 0.34483
# 	第3次kfold，label 1 - F1 score : 0.35484
# 	第4次kfold，label 1 - F1 score : 0.49275
# 	此參數kfold平均為0.38007250000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.21818
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.44068
# 	此參數kfold平均為0.31926
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31746
# 	第2次kfold，label 1 - F1 score : 0.33898
# 	第3次kfold，label 1 - F1 score : 0.35821
# 	第4次kfold，label 1 - F1 score : 0.47059
# 	此參數kfold平均為0.37131000000000003
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.18868
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.41379
# 	此參數kfold平均為0.3051625
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32143
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.35714
# 	第4次kfold，label 1 - F1 score : 0.46667
# 	此參數kfold平均為0.3681275
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32143
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.35714
# 	第4次kfold，label 1 - F1 score : 0.44444
# 	此參數kfold平均為0.36257
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31034
# 	第2次kfold，label 1 - F1 score : 0.31579
# 	第3次kfold，label 1 - F1 score : 0.34483
# 	第4次kfold，label 1 - F1 score : 0.43077
# 	此參數kfold平均為0.35043250000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.19231
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.2963
# 	第4次kfold，label 1 - F1 score : 0.39286
# 	此參數kfold平均為0.30218500000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32787
# 	第2次kfold，label 1 - F1 score : 0.34483
# 	第3次kfold，label 1 - F1 score : 0.35484
# 	第4次kfold，label 1 - F1 score : 0.49275
# 	此參數kfold平均為0.38007250000000004
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.21818
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.44068
# 	此參數kfold平均為0.31926
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31746
# 	第2次kfold，label 1 - F1 score : 0.33898
# 	第3次kfold，label 1 - F1 score : 0.35821
# 	第4次kfold，label 1 - F1 score : 0.47059
# 	此參數kfold平均為0.37131000000000003
# tfidf para :  {'min_df': 3, 'max_df': 5, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.18868
# 	第2次kfold，label 1 - F1 score : 0.32727
# 	第3次kfold，label 1 - F1 score : 0.29091
# 	第4次kfold，label 1 - F1 score : 0.41379
# 	此參數kfold平均為0.3051625
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.54286
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.59701
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.566365
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52778
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.59701
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.562595
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51351
# 	第2次kfold，label 1 - F1 score : 0.48485
# 	第3次kfold，label 1 - F1 score : 0.55556
# 	第4次kfold，label 1 - F1 score : 0.58333
# 	此參數kfold平均為0.5343125000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5641
# 	第2次kfold，label 1 - F1 score : 0.49275
# 	第3次kfold，label 1 - F1 score : 0.58974
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.554505
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54286
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.57576
# 	此參數kfold平均為0.55238
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51852
# 	第2次kfold，label 1 - F1 score : 0.47222
# 	第3次kfold，label 1 - F1 score : 0.52381
# 	第4次kfold，label 1 - F1 score : 0.58667
# 	此參數kfold平均為0.5253049999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50746
# 	第2次kfold，label 1 - F1 score : 0.5
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.52669
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.54286
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.59701
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.566365
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52778
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.59701
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.562595
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51351
# 	第2次kfold，label 1 - F1 score : 0.48485
# 	第3次kfold，label 1 - F1 score : 0.55556
# 	第4次kfold，label 1 - F1 score : 0.58333
# 	此參數kfold平均為0.5343125000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5641
# 	第2次kfold，label 1 - F1 score : 0.49275
# 	第3次kfold，label 1 - F1 score : 0.58974
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.554505
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54286
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.57576
# 	此參數kfold平均為0.55238
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51852
# 	第2次kfold，label 1 - F1 score : 0.47222
# 	第3次kfold，label 1 - F1 score : 0.52381
# 	第4次kfold，label 1 - F1 score : 0.58667
# 	此參數kfold平均為0.5253049999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50746
# 	第2次kfold，label 1 - F1 score : 0.5
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.52669
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.54286
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.59701
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.566365
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.52778
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.59701
# 	第4次kfold，label 1 - F1 score : 0.61765
# 	此參數kfold平均為0.562595
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51351
# 	第2次kfold，label 1 - F1 score : 0.48485
# 	第3次kfold，label 1 - F1 score : 0.55556
# 	第4次kfold，label 1 - F1 score : 0.58333
# 	此參數kfold平均為0.5343125000000001
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.52174
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.5286949999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5641
# 	第2次kfold，label 1 - F1 score : 0.49275
# 	第3次kfold，label 1 - F1 score : 0.58974
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.554505
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.54286
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.57576
# 	此參數kfold平均為0.55238
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51852
# 	第2次kfold，label 1 - F1 score : 0.47222
# 	第3次kfold，label 1 - F1 score : 0.52381
# 	第4次kfold，label 1 - F1 score : 0.58667
# 	此參數kfold平均為0.5253049999999999
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.50746
# 	第2次kfold，label 1 - F1 score : 0.5
# 	第3次kfold，label 1 - F1 score : 0.54545
# 	第4次kfold，label 1 - F1 score : 0.55385
# 	此參數kfold平均為0.52669
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70886
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.76316
# 	此參數kfold平均為0.7058500000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70886
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.76316
# 	此參數kfold平均為0.7058500000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68293
# 	第2次kfold，label 1 - F1 score : 0.64
# 	第3次kfold，label 1 - F1 score : 0.65823
# 	第4次kfold，label 1 - F1 score : 0.71605
# 	此參數kfold平均為0.6743025
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65169
# 	第2次kfold，label 1 - F1 score : 0.65789
# 	第3次kfold，label 1 - F1 score : 0.72093
# 	第4次kfold，label 1 - F1 score : 0.71605
# 	此參數kfold平均為0.68664
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.69444
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.68719
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.64
# 	第3次kfold，label 1 - F1 score : 0.69663
# 	第4次kfold，label 1 - F1 score : 0.73171
# 	此參數kfold平均為0.6837525
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.63291
# 	第2次kfold，label 1 - F1 score : 0.66667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69565
# 	此參數kfold平均為0.665475
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70886
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.76316
# 	此參數kfold平均為0.7058500000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70886
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.76316
# 	此參數kfold平均為0.7058500000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68293
# 	第2次kfold，label 1 - F1 score : 0.64
# 	第3次kfold，label 1 - F1 score : 0.65823
# 	第4次kfold，label 1 - F1 score : 0.71605
# 	此參數kfold平均為0.6743025
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65169
# 	第2次kfold，label 1 - F1 score : 0.65789
# 	第3次kfold，label 1 - F1 score : 0.72093
# 	第4次kfold，label 1 - F1 score : 0.71605
# 	此參數kfold平均為0.68664
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.69444
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.68719
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.64
# 	第3次kfold，label 1 - F1 score : 0.69663
# 	第4次kfold，label 1 - F1 score : 0.73171
# 	此參數kfold平均為0.6837525
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.63291
# 	第2次kfold，label 1 - F1 score : 0.66667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69565
# 	此參數kfold平均為0.665475
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70886
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.76316
# 	此參數kfold平均為0.7058500000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.1, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.70886
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.67532
# 	第4次kfold，label 1 - F1 score : 0.76316
# 	此參數kfold平均為0.7058500000000001
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.01, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68293
# 	第2次kfold，label 1 - F1 score : 0.64
# 	第3次kfold，label 1 - F1 score : 0.65823
# 	第4次kfold，label 1 - F1 score : 0.71605
# 	此參數kfold平均為0.6743025
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.69231
# 	第2次kfold，label 1 - F1 score : 0.67606
# 	第3次kfold，label 1 - F1 score : 0.60274
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.67086
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65169
# 	第2次kfold，label 1 - F1 score : 0.65789
# 	第3次kfold，label 1 - F1 score : 0.72093
# 	第4次kfold，label 1 - F1 score : 0.71605
# 	此參數kfold平均為0.68664
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.0001, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.67532
# 	第2次kfold，label 1 - F1 score : 0.69444
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.71233
# 	此參數kfold平均為0.68719
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.64
# 	第3次kfold，label 1 - F1 score : 0.69663
# 	第4次kfold，label 1 - F1 score : 0.73171
# 	此參數kfold平均為0.6837525
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 2}
# 	第1次kfold，label 1 - F1 score : 0.63291
# 	第2次kfold，label 1 - F1 score : 0.66667
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.69565
# 	此參數kfold平均為0.665475
# 調參完成 最佳參數為 :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)} {'min_samples_split': 0.1, 'min_samples_leaf': 1}

# %%
tfidf_want_parameters
# Out:
# {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}

# %%
model_want_parameters
# Out:
# {'min_samples_split': 0.1, 'min_samples_leaf': 1}

# %% [raw]
# tfidf_want_parameters = {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}

# %% [raw]
# model_want_parameters = {'min_samples_split': 1e-07, 'min_samples_leaf': 1}

# %%
tfidf = TfidfVectorizer( norm='l2' , encoding='utf-8' , stop_words='english')
ML_model= DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=1e-07,min_samples_leaf= 1,max_features=None,random_state=7)

tfidf.set_params( **tfidf_want_parameters )
ML_model.set_params( **model_want_parameters )

tfidf.fit(train.loc[np.where(train_label.values==1)[0]].tweet.apply(lambda x: np.str_(x)) ) 
tfidf_train = tfidf.transform(train.tweet.apply(lambda x: np.str_(x))) 
tfidf_test = tfidf.transform(test.tweet.apply(lambda x: np.str_(x)))

ML_model.fit( tfidf_train , train_label )
pred = ML_model.predict( tfidf_test )

print( classification_report(test_label,pred,digits=5).split()[12])  
print( classification_report(test_label,pred,digits=5) )
# Out:
# 0.86154
#               precision    recall  f1-score   support
#
#            0    0.99949   0.99986   0.99967     13818
#            1    0.93333   0.80000   0.86154        35
#
#    micro avg    0.99935   0.99935   0.99935     13853
#    macro avg    0.96641   0.89993   0.93061     13853
# weighted avg    0.99933   0.99935   0.99933     13853

# %% [raw]
# 結論 : 看過答案且finetune 非常棒!

# %%
train_words = tfidf.get_feature_names()

print("feature:",len(train_words))
print('extract_word:', train_words)
# Out:
# feature: 288
# extract_word: ['1st', 'acetaminophen', 'adderall', 'af', 'alarm', 'amp drink', 'amp hospice', 'amp hospice taking', 'amp im', 'antibiotics', 'antibiotics amp', 'anxiety', 'anxiety meds', 'arm', 'asked', 'asleep', 'away', 'away adderall', 'baby', 'bad', 'barely', 'bc', 'bed', 'best', 'best friend', 'better', 'birth', 'birth control', 'blood', 'botox', 'bottle', 'bottle tums', 'bring', 'button', 'came', 'canadiankelli', 'case', 'castor', 'castor oil', 'cause', 'chloemugg', 'cold', 'contractions', 'control', 'cough', 'currently', 'currently morphine', 'currently morphine drip', 'daily', 'damn', 'day', 'days', 'delicious', 'diabetics', 'diclectin', 'did', 'didnt', 'die', 'doctor', 'does', 'dont need', 'dont work', 'dose', 'drink', 'drip', 'drip amp', 'drip amp hospice', 'eat', 'effect', 'effects', 'end', 'ended', 'entonox', 'epidural', 'extra', 'fact', 'faster', 'fat', 'feel', 'feel like', 'feel sick', 'feeling', 'finally', 'fine', 'flu', 'flu medication', 'friend', 'fucking', 'gain', 'gaviscon', 'getting', 'getting nexplanon', 'giving', 'gmo', 'gmo insulin', 'god', 'goes', 'going', 'gonna', 'good', 'got', 'great', 'hair', 'happy', 'hard', 'hate', 'havent', 'having', 'head', 'headache', 'heartburn', 'help', 'helps', 'hey', 'high', 'holy', 'home', 'hope', 'hospice', 'hospice taking', 'hospice taking trying', 'hour', 'hours', 'http', 'https', 'hudson', 'hurt', 'husband', 'ibuprofen', 'ill', 'im getting', 'im getting nexplanon', 'im giving', 'im just', 'im scared', 'im tired', 'imma', 'infection', 'insulin', 'iud', 'ive', 'just make', 'just started', 'just want', 'kicking', 'kids', 'know', 'literally', 'little', 'lol', 'longer', 'look', 'love', 'lungs', 'make', 'make feel', 'makes', 'makes feel', 'massive', 'medication', 'medicine', 'meds', 'meds make', 'mom', 'morphine', 'morphine drip', 'morphine drip amp', 'muscle', 'muscle relaxer', 'muscle relaxers', 'nasal', 'nasal spray', 'need', 'need tums', 'needs', 'new', 'nexplanon', 'night', 'noct_harley', 'nurse', 'nyquil', 'oh', 'oil', 'orange', 'otc', 'pain', 'pain meds', 'painkillers', 'patch', 'people', 'person', 'pill', 'pills', 'pitocin', 'point', 'preggo', 'pregnancy', 'pregnant', 'prenatal', 'prenatal vitamins', 'prenatals', 'properly', 'real', 'really', 'regular', 'relaxer', 'relaxers', 'reminds', 'ridiculous', 'right', 'room', 'room amp', 'run', 'said', 'scared', 'set', 'shit', 'shot', 'shouldnt', 'sick', 'sleep', 'sleeping', 'sleepy', 'son', 'soon', 'sore', 'sounds', 'spray', 'starbucks', 'start', 'started', 'steroid', 'steroids', 'stop', 'stuff', 'sucked', 'sudafed', 'super', 'sure', 'swear', 'switching', 'taking', 'taking trying', 'thank', 'thank god', 'thanks', 'thats', 'thing', 'think', 'think im', 'throat', 'time', 'times', 'tired', 'today', 'told', 'tonight', 'took', 'tried', 'try', 'trying', 'tums', 'twice', 'tylenol', 'tylenol amp', 'tylenol3', 'type', 'vaccine', 'vitamins', 'wakes', 'wanna', 'want', 'water', 'went', 'whooping', 'whooping cough', 'wine', 'wonderful', 'wont', 'work', 'working', 'world', 'worst', 'wouldnt', 'yall', 'yeah', 'yep', 'zantac']

# %% [markdown]
# # 第二種 單個DT 單純2020資料transform 但fit時學了2018 label True
#
# ## TF-IDF
#
# fit :
#
# * 2020 train label - True
# * 2018 label - True
#
# transform :
#
# * 2020 train label - True & False

# %%
trainpath2018 = path+'AnnotationDRUGSInTweets_EMNLPChallenge18_TrainingSetClean.csv' 
trainpathori = path+'task1_training.csv'
devpath = path+'task1_validation.csv'

train2018=pd.read_csv(trainpath2018)
trainori=pd.read_csv(trainpathori)
dev=pd.read_csv(devpath)
# trainori = pd.concat([trainori,dev])

#trainori = trainori.rename(columns={"class": "label"})

train2018 = train2018.rename(columns={"comment_text": "tweet"})
train2018 = train2018.rename(columns={"toxic": "class"})
train2018one = train2018[train2018['class']==1]
train2018zero = train2018[train2018['class']==0]

# %%
train , train_label = df_(trainori)

# %%
train2018one.shape
# Out:
# (4975, 3)

# %%
train2018zero.shape
# Out:
# (4647, 3)

# %%
fit_train_ = pd.concat([trainori,train2018one])

# %%
fit_train , fit_train_label = df_(fit_train_)

# %%
fit_train.shape
# Out:
# (60394, 2)

# %%
print('train - label 1   : ' , len(train[train.label==1]))
print('train - label 0   : ' , len(train[train.label==0]))
print('fit train - label 1   : ' , len(fit_train[fit_train.label==1]) , ' = 146 + 4975')
print('dev   - label 1   : ' , len(test[test.label==1]))
print('dev   - label 0   : ' , len(test[test.label==0]))
# Out:
# train - label 1   :  146
# train - label 0   :  55273
# fit train - label 1   :  5121  = 146 + 4975
# dev   - label 1   :  35
# dev   - label 0   :  13818

# %%
tfidf_want_parameters =  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
model_want_parameters =  {'min_samples_split': 0.1, 'min_samples_leaf': 1}

# %%
tfidf = TfidfVectorizer( norm='l2' , encoding='utf-8' , stop_words='english')
ML_model= DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=1e-07,min_samples_leaf= 1,max_features=None,random_state=7)

tfidf.set_params( **tfidf_want_parameters )
ML_model.set_params( **model_want_parameters )

tfidf.fit(fit_train.loc[np.where(fit_train_label.values==1)[0]].tweet.apply(lambda x: np.str_(x)) ) 
tfidf_train = tfidf.transform(train.tweet.apply(lambda x: np.str_(x))) 
tfidf_test = tfidf.transform(test.tweet.apply(lambda x: np.str_(x)))

ML_model.fit( tfidf_train , train_label )
pred = ML_model.predict( tfidf_test )

print( classification_report(test_label,pred,digits=5).split()[12])  
print( classification_report(test_label,pred,digits=5) )
# Out:
# 0.74576
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99986   0.99946     13818
#            1    0.91667   0.62857   0.74576        35
#
#    micro avg    0.99892   0.99892   0.99892     13853
#    macro avg    0.95786   0.81421   0.87261     13853
# weighted avg    0.99885   0.99892   0.99882     13853

# %% [raw]
# 可得知 : 若用2018當fit 會使同個參數的結果下降

# %% [raw]
# 若幫這種fit 專門調參如何?

# %%
tfidf_parameters = { 
'min_df': [2,3,4,5],
'max_df' : [10,11,12,13,14,15,30],
'ngram_range' : [(1,2),(1,3),(1,4)]
}

ML_model_parameters = { 
'min_samples_split': [1e-03,1e-07],
'min_samples_leaf' : [1], 
}

ML_model= DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=0.1,max_features=None,random_state=7)
cv_times = 4

# %%
tfidf = TfidfVectorizer( norm='l2' , encoding='utf-8' , stop_words='english')
kf = StratifiedKFold( n_splits = cv_times )
kf.get_n_splits(train,train_label)

tunelist_tfidf = [ dict( zip( tfidf_parameters , v ) ) for v in product ( *tfidf_parameters.values() ) ]
tunelist_ML_model = [ dict( zip( ML_model_parameters , v ) ) for v in product ( *ML_model_parameters.values() ) ]

tfidf_parameter_best_scores = []
ML_model_best_scores_parameter = []

for tfidf_parameter in tunelist_tfidf :

    tfidf.set_params( **tfidf_parameter )
    ML_model_parameter_scores = []

    for ML_model_parameter in tunelist_ML_model :

        ML_model.set_params( **ML_model_parameter )
        cv_scores_just_care_label_1_F1 = []

        num = 1

        print( 'tfidf para : ' , tfidf_parameter )
        print( 'Model para : ' , ML_model_parameter)

        for train_index , test_index in kf.split(train,train_label):

            cv_train , cv_test = train.loc[train_index], train.loc[test_index]
            cv_train_label , cv_test_label = train_label[train_index], train_label[test_index]

            tfidf.fit(fit_train.loc[np.where(fit_train_label.values==1)[0]].tweet.apply(lambda x: np.str_(x)) ) 

            cv_train = tfidf.transform( cv_train.tweet.apply( lambda x: np.str_(x) ) ) 
            cv_test = tfidf.transform( cv_test.tweet.apply( lambda x: np.str_(x) ) )

            ML_model.fit(cv_train,cv_train_label,)
            cv_pred = ML_model.predict(cv_test)

            cv_scores_just_care_label_1_F1.append( float(classification_report(cv_test_label,cv_pred,digits=5).split()[12]) )
            now_score = float(classification_report(cv_test_label,cv_pred,digits=5).split()[12])
            print('\t第'+str(num)+'次kfold，label 1 - F1 score : ' + str(now_score))

            num+=1

        ML_model_parameter_scores.append(np.mean(cv_scores_just_care_label_1_F1))
        print('\t此參數kfold平均為'+str(np.mean(cv_scores_just_care_label_1_F1)))
    tfidf_parameter_best_scores.append( np.max( np.array(ML_model_parameter_scores) ) )
    ML_model_best_scores_parameter.append(tunelist_ML_model[ np.argmax(np.array(ML_model_parameter_scores))] )

print('調參完成 最佳參數為 : ' , tunelist_tfidf[np.argmax(np.array(tfidf_parameter_best_scores))] ,  ML_model_best_scores_parameter[np.argmax(np.array(tfidf_parameter_best_scores))] )
tfidf_want_parameters , model_want_parameters = tunelist_tfidf[np.argmax(np.array(tfidf_parameter_best_scores))] ,  ML_model_best_scores_parameter[np.argmax(np.array(tfidf_parameter_best_scores))]
# Out:
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64516
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.65574
# 	第4次kfold，label 1 - F1 score : 0.75862
# 	此參數kfold平均為0.6512425
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61765
# 	第2次kfold，label 1 - F1 score : 0.47273
# 	第3次kfold，label 1 - F1 score : 0.61765
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.5936750000000001
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63492
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.65574
# 	第4次kfold，label 1 - F1 score : 0.74576
# 	此參數kfold平均為0.640685
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62687
# 	第2次kfold，label 1 - F1 score : 0.50847
# 	第3次kfold，label 1 - F1 score : 0.625
# 	第4次kfold，label 1 - F1 score : 0.64706
# 	此參數kfold平均為0.60185
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63492
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.65574
# 	第4次kfold，label 1 - F1 score : 0.74576
# 	此參數kfold平均為0.640685
# tfidf para :  {'min_df': 2, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62687
# 	第2次kfold，label 1 - F1 score : 0.50847
# 	第3次kfold，label 1 - F1 score : 0.625
# 	第4次kfold，label 1 - F1 score : 0.64706
# 	此參數kfold平均為0.60185
# tfidf para :  {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63333
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.62295
# 	第4次kfold，label 1 - F1 score : 0.80645
# 	此參數kfold平均為0.6472625
# tfidf para :  {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.625
# 	第2次kfold，label 1 - F1 score : 0.49123
# 	第3次kfold，label 1 - F1 score : 0.61765
# 	第4次kfold，label 1 - F1 score : 0.71642
# 	此參數kfold平均為0.612575
# tfidf para :  {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65574
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.6129
# 	第4次kfold，label 1 - F1 score : 0.81967
# 	此參數kfold平均為0.6536575
# tfidf para :  {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.63636
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.638285
# tfidf para :  {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65574
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.6129
# 	第4次kfold，label 1 - F1 score : 0.81967
# 	此參數kfold平均為0.6536575
# tfidf para :  {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63636
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.63636
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.638285
# tfidf para :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.76667
# 	此參數kfold平均為0.71157
# tfidf para :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72464
# 	第2次kfold，label 1 - F1 score : 0.6129
# 	第3次kfold，label 1 - F1 score : 0.69841
# 	第4次kfold，label 1 - F1 score : 0.73846
# 	此參數kfold平均為0.6936024999999999
# tfidf para :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.7
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7033125
# tfidf para :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73529
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.73016
# 	第4次kfold，label 1 - F1 score : 0.71429
# 	此參數kfold平均為0.6974775000000001
# tfidf para :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.7
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7033125
# tfidf para :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73529
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.73016
# 	第4次kfold，label 1 - F1 score : 0.71429
# 	此參數kfold平均為0.6974775000000001
# tfidf para :  {'min_df': 2, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7036475
# tfidf para :  {'min_df': 2, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68571
# 	第2次kfold，label 1 - F1 score : 0.63333
# 	第3次kfold，label 1 - F1 score : 0.67692
# 	第4次kfold，label 1 - F1 score : 0.76471
# 	此參數kfold平均為0.6901675
# tfidf para :  {'min_df': 2, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72727
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.70085
# tfidf para :  {'min_df': 2, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71429
# 	第2次kfold，label 1 - F1 score : 0.57627
# 	第3次kfold，label 1 - F1 score : 0.65625
# 	第4次kfold，label 1 - F1 score : 0.72727
# 	此參數kfold平均為0.66852
# tfidf para :  {'min_df': 2, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72727
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.70085
# tfidf para :  {'min_df': 2, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71429
# 	第2次kfold，label 1 - F1 score : 0.57627
# 	第3次kfold，label 1 - F1 score : 0.65625
# 	第4次kfold，label 1 - F1 score : 0.72727
# 	此參數kfold平均為0.66852
# tfidf para :  {'min_df': 2, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.7036475
# tfidf para :  {'min_df': 2, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68571
# 	第2次kfold，label 1 - F1 score : 0.63333
# 	第3次kfold，label 1 - F1 score : 0.67692
# 	第4次kfold，label 1 - F1 score : 0.76471
# 	此參數kfold平均為0.6901675
# tfidf para :  {'min_df': 2, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72727
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.70085
# tfidf para :  {'min_df': 2, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71429
# 	第2次kfold，label 1 - F1 score : 0.57627
# 	第3次kfold，label 1 - F1 score : 0.65625
# 	第4次kfold，label 1 - F1 score : 0.72727
# 	此參數kfold平均為0.66852
# tfidf para :  {'min_df': 2, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72727
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.7541
# 	此參數kfold平均為0.70085
# tfidf para :  {'min_df': 2, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.71429
# 	第2次kfold，label 1 - F1 score : 0.57627
# 	第3次kfold，label 1 - F1 score : 0.65625
# 	第4次kfold，label 1 - F1 score : 0.72727
# 	此參數kfold平均為0.66852
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72727
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.71875
# 	此參數kfold平均為0.68947
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72464
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.6875
# 	第4次kfold，label 1 - F1 score : 0.72222
# 	此參數kfold平均為0.6861325
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.73016
# 	此參數kfold平均為0.7002925000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68571
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.65625
# 	第4次kfold，label 1 - F1 score : 0.70423
# 	此參數kfold平均為0.6694425
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.73846
# 	第2次kfold，label 1 - F1 score : 0.62069
# 	第3次kfold，label 1 - F1 score : 0.71186
# 	第4次kfold，label 1 - F1 score : 0.73016
# 	此參數kfold平均為0.7002925000000001
# tfidf para :  {'min_df': 2, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.68571
# 	第2次kfold，label 1 - F1 score : 0.63158
# 	第3次kfold，label 1 - F1 score : 0.65625
# 	第4次kfold，label 1 - F1 score : 0.70423
# 	此參數kfold平均為0.6694425
# tfidf para :  {'min_df': 2, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.6
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.71429
# 	此參數kfold平均為0.684635
# tfidf para :  {'min_df': 2, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.72222
# 	第2次kfold，label 1 - F1 score : 0.59016
# 	第3次kfold，label 1 - F1 score : 0.70769
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.671685
# tfidf para :  {'min_df': 2, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.72464
# 	此參數kfold平均為0.689765
# tfidf para :  {'min_df': 2, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.74286
# 	第2次kfold，label 1 - F1 score : 0.58462
# 	第3次kfold，label 1 - F1 score : 0.67692
# 	第4次kfold，label 1 - F1 score : 0.68493
# 	此參數kfold平均為0.6723325
# tfidf para :  {'min_df': 2, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.75758
# 	第2次kfold，label 1 - F1 score : 0.61017
# 	第3次kfold，label 1 - F1 score : 0.66667
# 	第4次kfold，label 1 - F1 score : 0.72464
# 	此參數kfold平均為0.689765
# tfidf para :  {'min_df': 2, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.74286
# 	第2次kfold，label 1 - F1 score : 0.58462
# 	第3次kfold，label 1 - F1 score : 0.67692
# 	第4次kfold，label 1 - F1 score : 0.68493
# 	此參數kfold平均為0.6723325
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.50794
# 	第2次kfold，label 1 - F1 score : 0.44828
# 	第3次kfold，label 1 - F1 score : 0.57627
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.54979
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48485
# 	第2次kfold，label 1 - F1 score : 0.42105
# 	第3次kfold，label 1 - F1 score : 0.50794
# 	第4次kfold，label 1 - F1 score : 0.53968
# 	此參數kfold平均為0.48838000000000004
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.50794
# 	第2次kfold，label 1 - F1 score : 0.44828
# 	第3次kfold，label 1 - F1 score : 0.57627
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.54979
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48485
# 	第2次kfold，label 1 - F1 score : 0.42105
# 	第3次kfold，label 1 - F1 score : 0.50794
# 	第4次kfold，label 1 - F1 score : 0.53968
# 	此參數kfold平均為0.48838000000000004
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.50794
# 	第2次kfold，label 1 - F1 score : 0.44828
# 	第3次kfold，label 1 - F1 score : 0.57627
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.54979
# tfidf para :  {'min_df': 3, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48485
# 	第2次kfold，label 1 - F1 score : 0.42105
# 	第3次kfold，label 1 - F1 score : 0.50794
# 	第4次kfold，label 1 - F1 score : 0.53968
# 	此參數kfold平均為0.48838000000000004
# tfidf para :  {'min_df': 3, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.48276
# 	第3次kfold，label 1 - F1 score : 0.56667
# 	第4次kfold，label 1 - F1 score : 0.67797
# 	此參數kfold平均為0.5568500000000001
# tfidf para :  {'min_df': 3, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51515
# 	第2次kfold，label 1 - F1 score : 0.5
# 	第3次kfold，label 1 - F1 score : 0.50794
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.5236299999999999
# tfidf para :  {'min_df': 3, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.48276
# 	第3次kfold，label 1 - F1 score : 0.56667
# 	第4次kfold，label 1 - F1 score : 0.67797
# 	此參數kfold平均為0.5568500000000001
# tfidf para :  {'min_df': 3, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51515
# 	第2次kfold，label 1 - F1 score : 0.5
# 	第3次kfold，label 1 - F1 score : 0.50794
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.5236299999999999
# tfidf para :  {'min_df': 3, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.5
# 	第2次kfold，label 1 - F1 score : 0.48276
# 	第3次kfold，label 1 - F1 score : 0.56667
# 	第4次kfold，label 1 - F1 score : 0.67797
# 	此參數kfold平均為0.5568500000000001
# tfidf para :  {'min_df': 3, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.51515
# 	第2次kfold，label 1 - F1 score : 0.5
# 	第3次kfold，label 1 - F1 score : 0.50794
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.5236299999999999
# tfidf para :  {'min_df': 3, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64615
# 	第2次kfold，label 1 - F1 score : 0.54237
# 	第3次kfold，label 1 - F1 score : 0.59375
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.6235325
# tfidf para :  {'min_df': 3, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62857
# 	第2次kfold，label 1 - F1 score : 0.54839
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.54545
# 	此參數kfold平均為0.563415
# tfidf para :  {'min_df': 3, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64615
# 	第2次kfold，label 1 - F1 score : 0.54237
# 	第3次kfold，label 1 - F1 score : 0.59375
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.6235325
# tfidf para :  {'min_df': 3, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62857
# 	第2次kfold，label 1 - F1 score : 0.54839
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.54545
# 	此參數kfold平均為0.563415
# tfidf para :  {'min_df': 3, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.64615
# 	第2次kfold，label 1 - F1 score : 0.54237
# 	第3次kfold，label 1 - F1 score : 0.59375
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.6235325
# tfidf para :  {'min_df': 3, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62857
# 	第2次kfold，label 1 - F1 score : 0.54839
# 	第3次kfold，label 1 - F1 score : 0.53125
# 	第4次kfold，label 1 - F1 score : 0.54545
# 	此參數kfold平均為0.563415
# tfidf para :  {'min_df': 3, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.55172
# 	第3次kfold，label 1 - F1 score : 0.60317
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.633355
# tfidf para :  {'min_df': 3, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63768
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.54795
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.57778
# tfidf para :  {'min_df': 3, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.55172
# 	第3次kfold，label 1 - F1 score : 0.60317
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.633355
# tfidf para :  {'min_df': 3, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63768
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.54795
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.57778
# tfidf para :  {'min_df': 3, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.55172
# 	第3次kfold，label 1 - F1 score : 0.60317
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.633355
# tfidf para :  {'min_df': 3, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63768
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.54795
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.57778
# tfidf para :  {'min_df': 3, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.55172
# 	第3次kfold，label 1 - F1 score : 0.60317
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.633355
# tfidf para :  {'min_df': 3, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63768
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.54795
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.57778
# tfidf para :  {'min_df': 3, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.55172
# 	第3次kfold，label 1 - F1 score : 0.60317
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.633355
# tfidf para :  {'min_df': 3, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63768
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.54795
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.57778
# tfidf para :  {'min_df': 3, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.55172
# 	第3次kfold，label 1 - F1 score : 0.60317
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.633355
# tfidf para :  {'min_df': 3, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63768
# 	第2次kfold，label 1 - F1 score : 0.56667
# 	第3次kfold，label 1 - F1 score : 0.54795
# 	第4次kfold，label 1 - F1 score : 0.55882
# 	此參數kfold平均為0.57778
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.5614
# 	第3次kfold，label 1 - F1 score : 0.64407
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.646
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65714
# 	第2次kfold，label 1 - F1 score : 0.54839
# 	第3次kfold，label 1 - F1 score : 0.59016
# 	第4次kfold，label 1 - F1 score : 0.55072
# 	此參數kfold平均為0.5866025
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.5614
# 	第3次kfold，label 1 - F1 score : 0.64407
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.646
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65714
# 	第2次kfold，label 1 - F1 score : 0.54839
# 	第3次kfold，label 1 - F1 score : 0.59016
# 	第4次kfold，label 1 - F1 score : 0.55072
# 	此參數kfold平均為0.5866025
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.66667
# 	第2次kfold，label 1 - F1 score : 0.5614
# 	第3次kfold，label 1 - F1 score : 0.64407
# 	第4次kfold，label 1 - F1 score : 0.71186
# 	此參數kfold平均為0.646
# tfidf para :  {'min_df': 3, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.65714
# 	第2次kfold，label 1 - F1 score : 0.54839
# 	第3次kfold，label 1 - F1 score : 0.59016
# 	第4次kfold，label 1 - F1 score : 0.55072
# 	此參數kfold平均為0.5866025
# tfidf para :  {'min_df': 3, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62857
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.67857
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6204375
# tfidf para :  {'min_df': 3, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63889
# 	第2次kfold，label 1 - F1 score : 0.52308
# 	第3次kfold，label 1 - F1 score : 0.6129
# 	第4次kfold，label 1 - F1 score : 0.56757
# 	此參數kfold平均為0.58561
# tfidf para :  {'min_df': 3, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62857
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.67857
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6204375
# tfidf para :  {'min_df': 3, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63889
# 	第2次kfold，label 1 - F1 score : 0.52308
# 	第3次kfold，label 1 - F1 score : 0.6129
# 	第4次kfold，label 1 - F1 score : 0.56757
# 	此參數kfold平均為0.58561
# tfidf para :  {'min_df': 3, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.62857
# 	第2次kfold，label 1 - F1 score : 0.50794
# 	第3次kfold，label 1 - F1 score : 0.67857
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6204375
# tfidf para :  {'min_df': 3, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.63889
# 	第2次kfold，label 1 - F1 score : 0.52308
# 	第3次kfold，label 1 - F1 score : 0.6129
# 	第4次kfold，label 1 - F1 score : 0.56757
# 	此參數kfold平均為0.58561
# tfidf para :  {'min_df': 4, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47273
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.58182
# 	第4次kfold，label 1 - F1 score : 0.58182
# 	此參數kfold平均為0.52674
# tfidf para :  {'min_df': 4, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.53333
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.48601249999999996
# tfidf para :  {'min_df': 4, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47273
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.58182
# 	第4次kfold，label 1 - F1 score : 0.58182
# 	此參數kfold平均為0.52674
# tfidf para :  {'min_df': 4, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.53333
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.48601249999999996
# tfidf para :  {'min_df': 4, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47273
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.58182
# 	第4次kfold，label 1 - F1 score : 0.58182
# 	此參數kfold平均為0.52674
# tfidf para :  {'min_df': 4, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.53333
# 	第4次kfold，label 1 - F1 score : 0.57143
# 	此參數kfold平均為0.48601249999999996
# tfidf para :  {'min_df': 4, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45614
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.60377
# 	第4次kfold，label 1 - F1 score : 0.65517
# 	此參數kfold平均為0.5464175
# tfidf para :  {'min_df': 4, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44828
# 	第2次kfold，label 1 - F1 score : 0.36735
# 	第3次kfold，label 1 - F1 score : 0.51613
# 	第4次kfold，label 1 - F1 score : 0.57627
# 	此參數kfold平均為0.47700750000000003
# tfidf para :  {'min_df': 4, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45614
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.60377
# 	第4次kfold，label 1 - F1 score : 0.65517
# 	此參數kfold平均為0.5464175
# tfidf para :  {'min_df': 4, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44828
# 	第2次kfold，label 1 - F1 score : 0.36735
# 	第3次kfold，label 1 - F1 score : 0.51613
# 	第4次kfold，label 1 - F1 score : 0.57627
# 	此參數kfold平均為0.47700750000000003
# tfidf para :  {'min_df': 4, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45614
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.60377
# 	第4次kfold，label 1 - F1 score : 0.65517
# 	此參數kfold平均為0.5464175
# tfidf para :  {'min_df': 4, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44828
# 	第2次kfold，label 1 - F1 score : 0.36735
# 	第3次kfold，label 1 - F1 score : 0.51613
# 	第4次kfold，label 1 - F1 score : 0.57627
# 	此參數kfold平均為0.47700750000000003
# tfidf para :  {'min_df': 4, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.6129
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.50704
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.5537274999999999
# tfidf para :  {'min_df': 4, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.6129
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.50704
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.5537274999999999
# tfidf para :  {'min_df': 4, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.6129
# 	第2次kfold，label 1 - F1 score : 0.5283
# 	第3次kfold，label 1 - F1 score : 0.50704
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.5537274999999999
# tfidf para :  {'min_df': 4, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.49057
# 	第3次kfold，label 1 - F1 score : 0.57143
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.55796
# tfidf para :  {'min_df': 4, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.49057
# 	第3次kfold，label 1 - F1 score : 0.57143
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.55796
# tfidf para :  {'min_df': 4, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.49057
# 	第3次kfold，label 1 - F1 score : 0.57143
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.55796
# tfidf para :  {'min_df': 4, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.49057
# 	第3次kfold，label 1 - F1 score : 0.57143
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.55796
# tfidf para :  {'min_df': 4, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.49057
# 	第3次kfold，label 1 - F1 score : 0.57143
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.55796
# tfidf para :  {'min_df': 4, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.55556
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6046524999999999
# tfidf para :  {'min_df': 4, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.49057
# 	第3次kfold，label 1 - F1 score : 0.57143
# 	第4次kfold，label 1 - F1 score : 0.56667
# 	此參數kfold平均為0.55796
# tfidf para :  {'min_df': 4, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6021249999999999
# tfidf para :  {'min_df': 4, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.5625
# 	第4次kfold，label 1 - F1 score : 0.59016
# 	此參數kfold平均為0.5705375
# tfidf para :  {'min_df': 4, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6021249999999999
# tfidf para :  {'min_df': 4, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.5625
# 	第4次kfold，label 1 - F1 score : 0.59016
# 	此參數kfold平均為0.5705375
# tfidf para :  {'min_df': 4, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.54545
# 	第3次kfold，label 1 - F1 score : 0.58621
# 	第4次kfold，label 1 - F1 score : 0.66667
# 	此參數kfold平均為0.6021249999999999
# tfidf para :  {'min_df': 4, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.60317
# 	第2次kfold，label 1 - F1 score : 0.52632
# 	第3次kfold，label 1 - F1 score : 0.5625
# 	第4次kfold，label 1 - F1 score : 0.59016
# 	此參數kfold平均為0.5705375
# tfidf para :  {'min_df': 4, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.53571
# 	第3次kfold，label 1 - F1 score : 0.63158
# 	第4次kfold，label 1 - F1 score : 0.63492
# 	此參數kfold平均為0.603095
# tfidf para :  {'min_df': 4, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.57576
# 	第2次kfold，label 1 - F1 score : 0.4918
# 	第3次kfold，label 1 - F1 score : 0.5625
# 	第4次kfold，label 1 - F1 score : 0.56716
# 	此參數kfold平均為0.549305
# tfidf para :  {'min_df': 4, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.53571
# 	第3次kfold，label 1 - F1 score : 0.63158
# 	第4次kfold，label 1 - F1 score : 0.63492
# 	此參數kfold平均為0.603095
# tfidf para :  {'min_df': 4, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.57576
# 	第2次kfold，label 1 - F1 score : 0.4918
# 	第3次kfold，label 1 - F1 score : 0.5625
# 	第4次kfold，label 1 - F1 score : 0.56716
# 	此參數kfold平均為0.549305
# tfidf para :  {'min_df': 4, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.61017
# 	第2次kfold，label 1 - F1 score : 0.53571
# 	第3次kfold，label 1 - F1 score : 0.63158
# 	第4次kfold，label 1 - F1 score : 0.63492
# 	此參數kfold平均為0.603095
# tfidf para :  {'min_df': 4, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.57576
# 	第2次kfold，label 1 - F1 score : 0.4918
# 	第3次kfold，label 1 - F1 score : 0.5625
# 	第4次kfold，label 1 - F1 score : 0.56716
# 	此參數kfold平均為0.549305
# tfidf para :  {'min_df': 5, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32653
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.56
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4428325
# tfidf para :  {'min_df': 5, 'max_df': 10, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31373
# 	第2次kfold，label 1 - F1 score : 0.27907
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.40781500000000004
# tfidf para :  {'min_df': 5, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32653
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.56
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4428325
# tfidf para :  {'min_df': 5, 'max_df': 10, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31373
# 	第2次kfold，label 1 - F1 score : 0.27907
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.40781500000000004
# tfidf para :  {'min_df': 5, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32653
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.56
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4428325
# tfidf para :  {'min_df': 5, 'max_df': 10, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.31373
# 	第2次kfold，label 1 - F1 score : 0.27907
# 	第3次kfold，label 1 - F1 score : 0.5
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.40781500000000004
# tfidf para :  {'min_df': 5, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32653
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.56
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4428325
# tfidf para :  {'min_df': 5, 'max_df': 11, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.33962
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.53061
# 	第4次kfold，label 1 - F1 score : 0.5283
# 	此參數kfold平均為0.42741
# tfidf para :  {'min_df': 5, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32653
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.56
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4428325
# tfidf para :  {'min_df': 5, 'max_df': 11, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.33962
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.53061
# 	第4次kfold，label 1 - F1 score : 0.5283
# 	此參數kfold平均為0.42741
# tfidf para :  {'min_df': 5, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.32653
# 	第2次kfold，label 1 - F1 score : 0.375
# 	第3次kfold，label 1 - F1 score : 0.56
# 	第4次kfold，label 1 - F1 score : 0.5098
# 	此參數kfold平均為0.4428325
# tfidf para :  {'min_df': 5, 'max_df': 11, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.33962
# 	第2次kfold，label 1 - F1 score : 0.31111
# 	第3次kfold，label 1 - F1 score : 0.53061
# 	第4次kfold，label 1 - F1 score : 0.5283
# 	此參數kfold平均為0.42741
# tfidf para :  {'min_df': 5, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 12, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45902
# 	第2次kfold，label 1 - F1 score : 0.43137
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.512385
# tfidf para :  {'min_df': 5, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 12, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45902
# 	第2次kfold，label 1 - F1 score : 0.43137
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.512385
# tfidf para :  {'min_df': 5, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 12, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45902
# 	第2次kfold，label 1 - F1 score : 0.43137
# 	第3次kfold，label 1 - F1 score : 0.62069
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.512385
# tfidf para :  {'min_df': 5, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 13, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44444
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.4992875
# tfidf para :  {'min_df': 5, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 13, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44444
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.4992875
# tfidf para :  {'min_df': 5, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 13, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44444
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.4992875
# tfidf para :  {'min_df': 5, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 14, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44444
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.4992875
# tfidf para :  {'min_df': 5, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 14, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44444
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.4992875
# tfidf para :  {'min_df': 5, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.52218
# tfidf para :  {'min_df': 5, 'max_df': 14, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.44444
# 	第2次kfold，label 1 - F1 score : 0.38462
# 	第3次kfold，label 1 - F1 score : 0.62963
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.4992875
# tfidf para :  {'min_df': 5, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48148
# 	第2次kfold，label 1 - F1 score : 0.44444
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.5283
# 	此參數kfold平均為0.5174000000000001
# tfidf para :  {'min_df': 5, 'max_df': 15, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.40741
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.55556
# 	此參數kfold平均為0.5049625
# tfidf para :  {'min_df': 5, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48148
# 	第2次kfold，label 1 - F1 score : 0.44444
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.5283
# 	此參數kfold平均為0.5174000000000001
# tfidf para :  {'min_df': 5, 'max_df': 15, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.40741
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.55556
# 	此參數kfold平均為0.5049625
# tfidf para :  {'min_df': 5, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.48148
# 	第2次kfold，label 1 - F1 score : 0.44444
# 	第3次kfold，label 1 - F1 score : 0.61538
# 	第4次kfold，label 1 - F1 score : 0.5283
# 	此參數kfold平均為0.5174000000000001
# tfidf para :  {'min_df': 5, 'max_df': 15, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.46429
# 	第2次kfold，label 1 - F1 score : 0.40741
# 	第3次kfold，label 1 - F1 score : 0.59259
# 	第4次kfold，label 1 - F1 score : 0.55556
# 	此參數kfold平均為0.5049625
# tfidf para :  {'min_df': 5, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45614
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.48485
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.48751
# tfidf para :  {'min_df': 5, 'max_df': 30, 'ngram_range': (1, 2)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47619
# 	第2次kfold，label 1 - F1 score : 0.47273
# 	第3次kfold，label 1 - F1 score : 0.47761
# 	第4次kfold，label 1 - F1 score : 0.49123
# 	此參數kfold平均為0.47944000000000003
# tfidf para :  {'min_df': 5, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45614
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.48485
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.48751
# tfidf para :  {'min_df': 5, 'max_df': 30, 'ngram_range': (1, 3)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47619
# 	第2次kfold，label 1 - F1 score : 0.47273
# 	第3次kfold，label 1 - F1 score : 0.47761
# 	第4次kfold，label 1 - F1 score : 0.49123
# 	此參數kfold平均為0.47944000000000003
# tfidf para :  {'min_df': 5, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 0.001, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.45614
# 	第2次kfold，label 1 - F1 score : 0.47059
# 	第3次kfold，label 1 - F1 score : 0.48485
# 	第4次kfold，label 1 - F1 score : 0.53846
# 	此參數kfold平均為0.48751
# tfidf para :  {'min_df': 5, 'max_df': 30, 'ngram_range': (1, 4)}
# Model para :  {'min_samples_split': 1e-07, 'min_samples_leaf': 1}
# 	第1次kfold，label 1 - F1 score : 0.47619
# 	第2次kfold，label 1 - F1 score : 0.47273
# 	第3次kfold，label 1 - F1 score : 0.47761
# 	第4次kfold，label 1 - F1 score : 0.49123
# 	此參數kfold平均為0.47944000000000003
# 調參完成 最佳參數為 :  {'min_df': 2, 'max_df': 12, 'ngram_range': (1, 2)} {'min_samples_split': 0.001, 'min_samples_leaf': 1}

# %%
tfidf = TfidfVectorizer( norm='l2' , encoding='utf-8' , stop_words='english')
ML_model= DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=1e-07,min_samples_leaf= 1,max_features=None,random_state=7)

tfidf.set_params( **tfidf_want_parameters )
ML_model.set_params( **model_want_parameters )

tfidf.fit(fit_train.loc[np.where(fit_train_label.values==1)[0]].tweet.apply(lambda x: np.str_(x)) ) 
tfidf_train = tfidf.transform(train.tweet.apply(lambda x: np.str_(x))) 
tfidf_test = tfidf.transform(test.tweet.apply(lambda x: np.str_(x)))

ML_model.fit( tfidf_train , train_label )
pred = ML_model.predict( tfidf_test )

print( classification_report(test_label,pred,digits=5).split()[12])  
print( classification_report(test_label,pred,digits=5) )
# Out:
# 0.70968
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99964   0.99935     13818
#            1    0.81481   0.62857   0.70968        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.90694   0.81410   0.85451     13853
# weighted avg    0.99859   0.99870   0.99862     13853

# %% [raw]
# 結論 : 將全部2018及原本train - True 一起當作 TF-IDF 找關鍵字fit 的資料並不是個好想法

# %%
train_words = tfidf.get_feature_names()

print("feature:",len(train_words))
print("shape:",train_features.shape)
print('extract_word:', train_words)
# Out:
# feature: 246
# shape: (58937, 237)
# extract_word: ['1st', 'acetaminophen', 'adderall', 'advil', 'af', 'amp drink', 'amp im', 'anti', 'antibiotics', 'arm', 'arnica', 'asleep', 'baby', 'bad', 'bc', 'bed', 'benadryl', 'best', 'best friend', 'better', 'birth', 'birth control', 'botox', 'bottle', 'bottle tums', 'bring', 'button', 'cake', 'canadiankelli', 'castor', 'castor oil', 'cause', 'chloemugg', 'comfort', 'contractions', 'control', 'daily', 'day', 'diabetics', 'diclectin', 'did', 'didnt', 'die', 'doctor', 'does', 'don', 'dont', 'drink', 'drugs', 'eat', 'effects', 'end', 'entonox', 'epidural', 'extra', 'fact', 'faster', 'fat', 'feel', 'feel like', 'feel sick', 'feeling', 'finally', 'fine', 'flu', 'friend', 'fucking', 'gain', 'gain weight', 'gaviscon', 'getting', 'getting nexplanon', 'ginger', 'giving', 'gmo', 'gmo insulin', 'god', 'goes', 'going', 'gonna', 'good', 'got', 'great', 'hair', 'happy', 'hard', 'hate', 'havent', 'having', 'head', 'headache', 'help', 'helps', 'hey', 'high', 'home', 'hope', 'hour', 'hours', 'http', 'https', 'hurt', 'husband', 'ibuprofen', 'ill', 'im getting', 'im getting nexplanon', 'im just', 'imma', 'infection', 'insulin', 'ive', 'just want', 'kick', 'kicking', 'know', 'labour', 'like', 'literally', 'little', 'lol', 'longer', 'look', 'love', 'lungs', 'make', 'make feel', 'makes', 'makes feel', 'massive', 'medicine', 'meds', 'meds make', 'midol', 'morphine', 'muscle', 'muscle relaxer', 'muscle relaxers', 'nasal', 'nasal spray', 'need', 'need tums', 'needs', 'new', 'nexplanon', 'night', 'noct_harley', 'nurse', 'nyquil', 'oh', 'oil', 'orange', 'otc', 'pain', 'pain meds', 'painkillers', 'people', 'person', 'pill', 'pills', 'pm', 'pops', 'pregnancy', 'pregnant', 'prenatal', 'prenatal vitamins', 'prenatals', 'properly', 'real', 'really', 'relaxer', 'relaxers', 'reminds', 'ridiculous', 'room', 'room amp', 'rt', 'run', 'said', 'set', 'shit', 'shot', 'shouldnt', 'sick', 'sleep', 'sleeping', 'sleepy', 'son', 'soon', 'sore', 'sounds', 'spray', 'start', 'steroid', 'steroids', 'stop', 'strong', 'sucked', 'sudafed', 'sure', 'swear', 'switching', 'taking', 'thank', 'thank god', 'thanks', 'thing', 'think', 'think im', 'throat', 'time', 'times', 'tired', 'today', 'told', 'tonight', 'took', 'tried', 'try', 'trying', 'tums', 'twice', 'twitter', 'tylenol', 'tylenol amp', 'tylenol3', 'type', 'use', 'vitamins', 'wakes', 'wanna', 'want', 'water', 'weight', 'wine', 'wonderful', 'wont', 'work', 'worked', 'working', 'world', 'worst', 'wouldnt', 'wtf', 'yall', 'zantac']

# %% [markdown]
# # 第三種 552個DT fit時學了2018 label True transform的時候 包含146 train - true & 9筆 2018 data
#
# ## TF-IDF
#
# fit :
#
# * 2020 train label - True
#
# transform :
#
# * 2020 train label - True & False
# * 2018 label - True & False

# %%
trainpath2018 = path+'AnnotationDRUGSInTweets_EMNLPChallenge18_TrainingSetClean.csv' 
trainpathori = path+'task1_training.csv'
devpath = path+'task1_validation.csv'

train2018=pd.read_csv(trainpath2018)
trainori=pd.read_csv(trainpathori)
dev=pd.read_csv(devpath)
# trainori = pd.concat([trainori,dev])

#trainori = trainori.rename(columns={"class": "label"})

train2018 = train2018.rename(columns={"comment_text": "tweet"})
train2018 = train2018.rename(columns={"toxic": "class"})
train2018one = train2018[train2018['class']==1]
train2018zero = train2018[train2018['class']==0]

# %%
print(train2018one.shape[0])
# Out:
# 4975

# %%
print(train2018zero.shape[0])
# Out:
# 4647

# %%
(trainori[trainori['class']==0].shape[0]+train2018zero.shape[0])*0.0026
# Out:
# 155.792

# %%
155-146
# Out:
# 9

# %% [markdown]
# ### Train data

# %%
trainpath=path+'task1_training.xlsx'

# %%
train_ = pd.read_excel(trainpath)

# %%
train , train_label = df_(train_)

# %%
tfidf_want_parameters = {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 3)}

# %%
model_want_parameters = {'min_samples_split': 0.001, 'min_samples_leaf': 1}

# %%
devscore = [0 for i in range(len(dev))]

# %%
add_num = 9
len(train2018one)//add_num
# Out:
# 552

# %%
list_pred_1 = []

for time in range(len(train2018one)//add_num):
    print('第 '+str(time+1)+' 個Model : ')

    nine2018=train2018one[time*add_num:(time+1)*add_num]
    trainnew=pd.concat([trainori,nine2018,train2018zero])

    model = DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split = 0.1,max_features=None,random_state=7)
    
    traindf,traindf_label = df_(trainnew)

    tfidf = TfidfVectorizer( norm='l2' , encoding='utf-8' , stop_words='english')
    tfidf.set_params( **tfidf_want_parameters )
    model.set_params( **model_want_parameters )
    
    print('fit label - True 數量 :' , len(traindf[traindf['label']==1].tweet.apply(lambda x: np.str_(x))))
    tfidf.fit(traindf[traindf['label']==1].tweet.apply(lambda x: np.str_(x))) 

    train_features = tfidf.transform(traindf.tweet.apply(lambda x: np.str_(x)))  #You need to convert the dtype object to unicode string as is clearly mentioned in the traceback.
    train_labels = traindf.label
    train_words = tfidf.get_feature_names()
#     print(len(train_words))
#     print(train_features.shape)

    model.fit(train_features,train_labels)

    devdf , val_labels  = df_(dev)

    val_features = tfidf.transform(devdf.tweet.apply(lambda x: np.str_(x)))  #You need to convert the dtype object to unicode string as is clearly mentioned in the traceback.
    val_words = tfidf.get_feature_names()

#     print(len(val_words))
#     print(val_features.shape)

    ans=model.predict(val_features)
    print(classification_report(val_labels,ans,digits=5))
    print(np.where(np.array(ans)==1)[0])
    list_pred_1 
    
    for i in np.where(ans==1)[0]:
        devscore[i]+=1
# Out:
# 第 1 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1901 1951 2439 2785 3651 3706 3970 3989 4930 5336 5507 6686
#  7130 7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 2 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99892   0.99964   0.99928     13818
#            1    0.80000   0.57143   0.66667        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.89946   0.78553   0.83297     13853
# weighted avg    0.99841   0.99856   0.99844     13853
#
# [  80 1640 1869 1901 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507
#  6686 7130 7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 3 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3989  4930  5336  5451  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11783]
# 第 4 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 5 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 6 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2360 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 7 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99978   0.99931     13818
#            1    0.86364   0.54286   0.66667        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.93124   0.77132   0.83299     13853
# weighted avg    0.99850   0.99863   0.99847     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7308
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 8 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 10006]
# 第 9 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1869 1951 2439 2785 2842 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 8985 9280 9431]
# 第 10 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 5787 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 11 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99892   0.99978   0.99935     13818
#            1    0.86957   0.57143   0.68966        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.93424   0.78561   0.84450     13853
# weighted avg    0.99859   0.99870   0.99857     13853
#
# [  80 1869 1951 2439 2598 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 12 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 12103]
# 第 13 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1621 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 14 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 15 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99978   0.99931     13818
#            1    0.86364   0.54286   0.66667        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.93124   0.77132   0.83299     13853
# weighted avg    0.99850   0.99863   0.99847     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7308
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 16 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 17 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 18 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3970  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 12103]
# 第 19 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99949   0.99913     13818
#            1    0.72000   0.51429   0.60000        35
#
#    micro avg    0.99827   0.99827   0.99827     13853
#    macro avg    0.85939   0.75689   0.79957     13853
# weighted avg    0.99807   0.99827   0.99812     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3970  3989  4930  5318
#   5336  5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431
#  12103]
# 第 20 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2836 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 21 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  2836  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 10149]
# 第 22 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3989  4930  5336  5507  6686
#   7130  7792  7906  8527  8728  8762  8820  9280  9431 12103]
# 第 23 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99949   0.99917     13818
#            1    0.73077   0.54286   0.62295        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.86481   0.77118   0.81106     13853
# weighted avg    0.99817   0.99834   0.99822     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7308  7792  7906  8527  8728  8762  8820  8985  9280  9431
#  12103 13379]
# 第 24 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99942   0.99910     13818
#            1    0.69231   0.51429   0.59016        35
#
#    micro avg    0.99820   0.99820   0.99820     13853
#    macro avg    0.84554   0.75685   0.79463     13853
# weighted avg    0.99800   0.99820   0.99806     13853
#
# [  80 1869 1951 2439 2785 2836 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7674 7792 7906 8084 8527 8728 8762 8820 8985 9280 9431]
# 第 25 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [   80  1869  1951  2439  2785  3651  3989  4930  5336  5507  6686  7130
#   7792  7906  8527  8728  8762  8820  9280  9431 13156]
# 第 26 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3989  4930  5336  5507  6686
#   7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 12241]
# 第 27 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 28 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 29 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1951 2439 2598 2785 2977 3651 3706 3989 4902 4930 5336 5507
#  6686 7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 30 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6418 6686
#  7130 7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 31 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3989  4930  5336  5507  6686
#   7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 12103 12241]
# 第 32 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99949   0.99913     13818
#            1    0.72000   0.51429   0.60000        35
#
#    micro avg    0.99827   0.99827   0.99827     13853
#    macro avg    0.85939   0.75689   0.79957     13853
# weighted avg    0.99807   0.99827   0.99812     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5242 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431 9577]
# 第 33 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 34 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99949   0.99913     13818
#            1    0.72000   0.51429   0.60000        35
#
#    micro avg    0.99827   0.99827   0.99827     13853
#    macro avg    0.85939   0.75689   0.79957     13853
# weighted avg    0.99807   0.99827   0.99812     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3989  4930  5336  5507  6686
#   6914  7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 10382
#  12241]
# 第 35 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8703 8728 8762 8820 9280 9431]
# 第 36 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4930 5336 5507 6686 7130 7792 7906
#  8527 8703 8728 8762 8820 9280 9431]
# 第 37 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99957   0.99920     13818
#            1    0.76000   0.54286   0.63333        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.87942   0.77121   0.81627     13853
# weighted avg    0.99824   0.99841   0.99828     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3970 3989 4930 5336 5507 6686
#  7051 7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 38 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1901  1951  2439  2785  2977  3651  3706  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 13648]
# 第 39 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80  141 1869 1901 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 40 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 41 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99971   0.99928     13818
#            1    0.82609   0.54286   0.65517        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.91247   0.77128   0.82722     13853
# weighted avg    0.99841   0.99856   0.99841     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 42 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99949   0.99913     13818
#            1    0.72000   0.51429   0.60000        35
#
#    micro avg    0.99827   0.99827   0.99827     13853
#    macro avg    0.85939   0.75689   0.79957     13853
# weighted avg    0.99807   0.99827   0.99812     13853
#
# [   80  1869  1951  2360  2439  2785  2977  3651  3706  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8703  8728  8762  8820  9280  9431
#  10741]
# 第 43 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 44 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 45 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 46 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3970 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 8985 9280 9431]
# 第 47 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 48 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 49 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2836 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 50 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 51 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80  784 1869 1951 2439 2785 3651 3706 3970 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 52 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99986   0.99935     13818
#            1    0.90476   0.54286   0.67857        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.95180   0.77136   0.83896     13853
# weighted avg    0.99861   0.99870   0.99854     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4930 5336 5507 6686 7130 7308 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 53 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 54 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80  784 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 55 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 56 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 57 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99978   0.99931     13818
#            1    0.86364   0.54286   0.66667        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.93124   0.77132   0.83299     13853
# weighted avg    0.99850   0.99863   0.99847     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4930 5336 5507 6555 6686 7130 7792
#  7906 8527 8703 8728 8762 8820 9280 9431]
# 第 58 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 59 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1869 1951 2439 2785 2836 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 8985 9280 9431]
# 第 60 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 61 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 62 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1621 1869 1951 2439 2785 2836 2977 3651 3970 3989 4930 5336 5507
#  6686 7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 63 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 64 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1621  1869  1951  2360  2439  2785  3651  3706  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11047]
# 第 65 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2360 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 66 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 13617]
# 第 67 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3989  4930  5336  5507  5660
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11853]
# 第 68 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80  784 1869 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 69 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 12103]
# 第 70 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80  784 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 71 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2836 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 72 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4843 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 73 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 74 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 75 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 76 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99971   0.99928     13818
#            1    0.82609   0.54286   0.65517        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.91247   0.77128   0.82722     13853
# weighted avg    0.99841   0.99856   0.99841     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 77 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1621  1869  1951  2439  2785  3651  3989  4930  5336  5507  6686
#   7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 12103]
# 第 78 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 79 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11853]
# 第 80 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 4954 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 81 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 82 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2360 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 83 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1362 1869 1951 2439 2785 3651 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8703 8728 8762 8820 9280 9431]
# 第 84 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99971   0.99928     13818
#            1    0.82609   0.54286   0.65517        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.91247   0.77128   0.82722     13853
# weighted avg    0.99841   0.99856   0.99841     13853
#
# [  80 1236 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 85 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3970  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 12103]
# 第 86 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3989  4930  5336  5507  6686
#   7130  7792  7906  8527  8728  8762  8820  9280  9431 12103]
# 第 87 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99957   0.99920     13818
#            1    0.76000   0.54286   0.63333        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.87942   0.77121   0.81627     13853
# weighted avg    0.99824   0.99841   0.99828     13853
#
# [  80 1621 1640 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507
#  6686 7130 7792 7906 8527 8728 8762 8820 8985 9280 9431]
# 第 88 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 89 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1236 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 90 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3989  4930  5336  5507  6686
#   7130  7792  7906  8527  8728  8762  8820  8985  9280  9431 11509 12103]
# 第 91 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 92 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80  784 1869 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 93 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 94 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 95 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2836 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 96 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 12103]
# 第 97 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99971   0.99928     13818
#            1    0.82609   0.54286   0.65517        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.91247   0.77128   0.82722     13853
# weighted avg    0.99841   0.99856   0.99841     13853
#
# [   80  1640  1869  1951  2439  2785  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 12103]
# 第 98 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99892   0.99978   0.99935     13818
#            1    0.86957   0.57143   0.68966        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.93424   0.78561   0.84450     13853
# ...
#    macro avg    0.91247   0.77128   0.82722     13853
# weighted avg    0.99841   0.99856   0.99841     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5241 5336 5507 6686 7130
#  7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 521 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3970  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11872]
# 第 522 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 523 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4930 5336 5507 6247 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 524 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1447 1869 1901 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507
#  6686 7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 525 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 13648]
# 第 526 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [   80  1869  1951  2439  2785  3651  3706  3970  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11758]
# 第 527 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4159 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9318 9431]
# 第 528 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4563 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 529 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1901 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 530 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1901 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 531 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99949   0.99913     13818
#            1    0.72000   0.51429   0.60000        35
#
#    micro avg    0.99827   0.99827   0.99827     13853
#    macro avg    0.85939   0.75689   0.79957     13853
# weighted avg    0.99807   0.99827   0.99812     13853
#
# [  80 1653 1869 1951 2439 2785 3651 3706 3834 3989 4930 5087 5336 5507
#  6686 7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 532 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99964   0.99924     13818
#            1    0.79167   0.54286   0.64407        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.89525   0.77125   0.82165     13853
# weighted avg    0.99832   0.99848   0.99834     13853
#
# [  80 1869 1901 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 533 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [    0    80   935  1869  1951  2439  2785  3651  3706  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 12801]
# 第 534 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1869 1951 2182 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 535 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1901 1951 2439 2785 3651 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 536 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [  80 1869 1901 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 537 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2360  2439  2785  2977  3651  3706  3989  4930  5336
#   5507  6686  7130  7792  7906  8527  8728  8762  8820  9280  9431 11562]
# 第 538 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99978   0.99928     13818
#            1    0.85714   0.51429   0.64286        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.92796   0.75703   0.82107     13853
# weighted avg    0.99841   0.99856   0.99838     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 539 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99949   0.99913     13818
#            1    0.72000   0.51429   0.60000        35
#
#    micro avg    0.99827   0.99827   0.99827     13853
#    macro avg    0.85939   0.75689   0.79957     13853
# weighted avg    0.99807   0.99827   0.99812     13853
#
# [  80 1869 1901 1951 2439 2785 3651 3989 4343 4930 5336 5507 6236 6686
#  7130 7637 7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 540 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99942   0.99910     13818
#            1    0.69231   0.51429   0.59016        35
#
#    micro avg    0.99820   0.99820   0.99820     13853
#    macro avg    0.84554   0.75685   0.79463     13853
# weighted avg    0.99800   0.99820   0.99806     13853
#
# [  80 1869 1901 1951 2360 2439 2785 2977 3651 3706 3989 4930 5336 5507
#  6686 7130 7792 7906 8505 8527 8703 8728 8762 8820 9280 9431]
# 第 541 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99957   0.99917     13818
#            1    0.75000   0.51429   0.61017        35
#
#    micro avg    0.99834   0.99834   0.99834     13853
#    macro avg    0.87439   0.75693   0.80467     13853
# weighted avg    0.99814   0.99834   0.99819     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4930  5336  5507
#   6686  7130  7792  7906  8527  8703  8728  8762  8820  9280  9431 12241]
# 第 542 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99986   0.99935     13818
#            1    0.90476   0.54286   0.67857        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.95180   0.77136   0.83896     13853
# weighted avg    0.99861   0.99870   0.99854     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4930 5336 5507 6686 7130 7308 7792
#  7906 8527 8728 8762 8820 9280 9431]
# 第 543 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3985 3989 4930 5336 5507 6686
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 544 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1901 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 545 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1901 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8728 8762 8820 9280 9431]
# 第 546 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1901 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 8527 8703 8728 8762 8820 9280 9431]
# 第 547 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99971   0.99928     13818
#            1    0.82609   0.54286   0.65517        35
#
#    micro avg    0.99856   0.99856   0.99856     13853
#    macro avg    0.91247   0.77128   0.82722     13853
# weighted avg    0.99841   0.99856   0.99841     13853
#
# [  80 1869 1901 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7308 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 548 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8703 8728 8762 8820 9280 9431]
# 第 549 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4930 5336 5507 6686 6689
#  7130 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 550 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99971   0.99924     13818
#            1    0.81818   0.51429   0.63158        35
#
#    micro avg    0.99848   0.99848   0.99848     13853
#    macro avg    0.90848   0.75700   0.81541     13853
# weighted avg    0.99831   0.99848   0.99831     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4930 5336 5507 6686 7130 7792
#  7906 8527 8703 8728 8762 8820 9280 9431]
# 第 551 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99964   0.99920     13818
#            1    0.78261   0.51429   0.62069        35
#
#    micro avg    0.99841   0.99841   0.99841     13853
#    macro avg    0.89069   0.75696   0.80995     13853
# weighted avg    0.99822   0.99841   0.99825     13853
#
# [  80 1869 1951 2439 2675 2785 3651 3706 3989 4930 5336 5507 6686 7130
#  7792 7906 7999 8527 8728 8762 8820 9280 9431]
# 第 552 個Model :
# fit label - True 數量 : 155
#               precision    recall  f1-score   support
#
#            0    0.99884   0.99986   0.99935     13818
#            1    0.90476   0.54286   0.67857        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.95180   0.77136   0.83896     13853
# weighted avg    0.99861   0.99870   0.99854     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4930 5336 5507 6555 6686 7130 7792
#  7906 8527 8728 8762 8820 9280 9431]

# %%
len(devscore)
# Out:
# 13853

# %%
len(dev)*0.0026
# Out:
# 36.0178

# %%
for threshold in range(1,len(dev)+1):
    devans=[0 for i in range(len(dev))]
    num = 0
    for i in range(len(devscore)):
        if(devscore[i]>threshold):
            devans[i]=1
            num+=1
        else : continue
    if(num==36):
        print(threshold)
# Out:
# 7
# 8

# %%
devans=[0 for i in range(len(dev))]
for i in range(len(devscore)):
    if(devscore[i]>551):
        devans[i]=1
    else : continue

print(classification_report(val_labels,devans,digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.99877   0.99986   0.99931     13818
#            1    0.90000   0.51429   0.65455        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.94939   0.75707   0.82693     13853
# weighted avg    0.99852   0.99863   0.99844     13853

# %% [raw]
# 結論 : 2018全用並不妥!

# %% [markdown]
# # 濾過的2018

# %%
# trainpath2018 =path+'gooddata2(2018)SVM.csv'
trainpath2018 =path+'new_svm_filter_2018.csv' 
trainpathori =path+'task1_training.csv'
devpath =path+'task1_validation.csv'

train2018=pd.read_csv(trainpath2018)
trainori=pd.read_csv(trainpathori)
dev=pd.read_csv(devpath)


train2018 = train2018.rename(columns={"comment_text": "tweet"})
train2018 = train2018.rename(columns={"toxic": "class"})
train2018one=train2018[train2018['class']==1]
train2018zero=train2018[train2018['class']==0]

# %%
train2018one.shape
# Out:
# (532, 4)

# %%
train2018zero.shape
# Out:
# (4593, 4)

# %%
(trainori[trainori['class']==0].shape[0]+train2018zero.shape[0])*0.0026
# Out:
# 155.6516

# %%
152-146
# Out:
# 6

# %%
devscore=[0 for i in range(len(dev))]

# %%
add_num = 9
len(train2018one)//add_num
# Out:
# 59

# %%
tfidf_want_parameters = {'min_df': 2, 'max_df': 11, 'ngram_range': (1, 3)}

# %%
model_want_parameters = {'min_samples_split': 0.001, 'min_samples_leaf': 1}

# %%
list_pred_1 = []

for time in range(len(train2018one)//add_num):
    print('第 '+str(time+1)+' 個Model : ')

    nine2018=train2018one[time*add_num:(time+1)*add_num]
    trainnew=pd.concat([trainori,nine2018,train2018zero])

    model = DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_split=1e-07, min_samples_leaf=1,max_features=None ,max_leaf_nodes=100,random_state=7)
    
    traindf , traindf_label = df_(trainnew)


    tfidf = TfidfVectorizer( norm='l2' , encoding='utf-8' , stop_words='english')
    tfidf.set_params( **tfidf_want_parameters )
    model.set_params( **model_want_parameters )
    
    tfidf.fit(traindf[traindf['label']==1].tweet.apply(lambda x: np.str_(x))) 

    train_features = tfidf.transform(traindf.tweet.apply(lambda x: np.str_(x)))  #You need to convert the dtype object to unicode string as is clearly mentioned in the traceback.
    train_labels = traindf.label
    train_words = tfidf.get_feature_names()
#     print(len(train_words))
#     print(train_features.shape)

    model.fit(train_features,train_labels)

    devdf , devdf_label = df_(dev)

    val_features = tfidf.transform(devdf.tweet.apply(lambda x: np.str_(x)))  #You need to convert the dtype object to unicode string as is clearly mentioned in the traceback.
    val_labels = devdf.label
    val_words = tfidf.get_feature_names()

#     print(len(val_words))
#     print(val_features.shape)

    ans=model.predict(val_features)
    print(classification_report(val_labels,ans,digits=5))
    print(np.where(np.array(ans)==1)[0])
    list_pred_1 
    
    for i in np.where(ans==1)[0]:
        devscore[i]+=1
# Out:
# 第 1 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 2 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 3 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686
#  7051 7130 7187 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 4 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99964   0.99939     13818
#            1    0.82143   0.65714   0.73016        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.91028   0.82839   0.86477     13853
# weighted avg    0.99868   0.99877   0.99870     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  5740 6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 5 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 6 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99986   0.99949     13818
#            1    0.92000   0.65714   0.76667        35
#
#    micro avg    0.99899   0.99899   0.99899     13853
#    macro avg    0.95957   0.82850   0.88308     13853
# weighted avg    0.99893   0.99899   0.99891     13853
#
# [  80  155 1869 1951 2439 2785 3651 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 7 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 8 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99978   0.99946     13818
#            1    0.88462   0.65714   0.75410        35
#
#    micro avg    0.99892   0.99892   0.99892     13853
#    macro avg    0.94187   0.82846   0.87678     13853
# weighted avg    0.99884   0.99892   0.99884     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 9 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99957   0.99935     13818
#            1    0.79310   0.65714   0.71875        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.89612   0.82835   0.85905     13853
# weighted avg    0.99861   0.99870   0.99864     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930
#   5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762
#   8820  9280  9431 11238 13620]
# 第 10 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 11 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8307 8527 8728 8762 8820 9280 9431]
# 第 12 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99964   0.99939     13818
#            1    0.82143   0.65714   0.73016        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.91028   0.82839   0.86477     13853
# weighted avg    0.99868   0.99877   0.99870     13853
#
# [  80  155  251 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336
#  5507 6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 13 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 14 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7556 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 15 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99986   0.99946     13818
#            1    0.91667   0.62857   0.74576        35
#
#    micro avg    0.99892   0.99892   0.99892     13853
#    macro avg    0.95786   0.81421   0.87261     13853
# weighted avg    0.99885   0.99892   0.99882     13853
#
# [  80 1869 1951 2439 2785 3651 3989 4218 4930 5336 5507 6686 7051 7130
#  7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 16 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 17 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99957   0.99931     13818
#            1    0.78571   0.62857   0.69841        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.89239   0.81407   0.84886     13853
# weighted avg    0.99852   0.99863   0.99855     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930  5336
#   5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762  8820
#   9280  9431 11228 13453]
# 第 18 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99957   0.99931     13818
#            1    0.78571   0.62857   0.69841        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.89239   0.81407   0.84886     13853
# weighted avg    0.99852   0.99863   0.99855     13853
#
# [  80 1362 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 5660
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9376 9431]
# 第 19 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99964   0.99935     13818
#            1    0.81481   0.62857   0.70968        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.90694   0.81410   0.85451     13853
# weighted avg    0.99859   0.99870   0.99862     13853
#
# [  80  719 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 20 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 21 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 22 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99978   0.99946     13818
#            1    0.88462   0.65714   0.75410        35
#
#    micro avg    0.99892   0.99892   0.99892     13853
#    macro avg    0.94187   0.82846   0.87678     13853
# weighted avg    0.99884   0.99892   0.99884     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 23 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 24 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686
#  7051 7130 7201 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 25 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3989 4218 4843 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 26 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99978   0.99946     13818
#            1    0.88462   0.65714   0.75410        35
#
#    micro avg    0.99892   0.99892   0.99892     13853
#    macro avg    0.94187   0.82846   0.87678     13853
# weighted avg    0.99884   0.99892   0.99884     13853
#
# [  80  155 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 27 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6100
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 28 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99964   0.99939     13818
#            1    0.82143   0.65714   0.73016        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.91028   0.82839   0.86477     13853
# weighted avg    0.99868   0.99877   0.99870     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930
#   5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762
#   8820  9280  9431 12082]
# 第 29 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99964   0.99939     13818
#            1    0.82143   0.65714   0.73016        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.91028   0.82839   0.86477     13853
# weighted avg    0.99868   0.99877   0.99870     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930
#   5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762
#   8820  9280  9431 12103]
# 第 30 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 31 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 32 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 33 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 34 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 35 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3989  4218  4930  5336
#   5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762  8820
#   9280  9431 13140]
# 第 36 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99964   0.99935     13818
#            1    0.81481   0.62857   0.70968        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.90694   0.81410   0.85451     13853
# weighted avg    0.99859   0.99870   0.99862     13853
#
# [  80 1869 1951 2439 2675 2785 3651 3706 3970 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 37 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 38 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 39 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 40 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 41 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99957   0.99931     13818
#            1    0.78571   0.62857   0.69841        35
#
#    micro avg    0.99863   0.99863   0.99863     13853
#    macro avg    0.89239   0.81407   0.84886     13853
# weighted avg    0.99852   0.99863   0.99855     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  6948 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431 9453]
# 第 42 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99957   0.99935     13818
#            1    0.79310   0.65714   0.71875        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.89612   0.82835   0.85905     13853
# weighted avg    0.99861   0.99870   0.99864     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930
#   5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762
#   8820  9280  9431 10657 10754]
# 第 43 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99957   0.99935     13818
#            1    0.79310   0.65714   0.71875        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.89612   0.82835   0.85905     13853
# weighted avg    0.99861   0.99870   0.99864     13853
#
# [   80   155  1869  1951  2439  2785  3651  3706  3989  4218  4930  5336
#   5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8757  8762
#   8820  9280  9431 11162 12857]
# 第 44 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99964   0.99935     13818
#            1    0.81481   0.62857   0.70968        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.90694   0.81410   0.85451     13853
# weighted avg    0.99859   0.99870   0.99862     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930  5336
#   5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762  8820
#   9280  9431 10897]
# 第 45 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  141  155 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 46 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 47 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 48 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99957   0.99935     13818
#            1    0.79310   0.65714   0.71875        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.89612   0.82835   0.85905     13853
# weighted avg    0.99861   0.99870   0.99864     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4754
#   4930  5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728
#   8762  8820  9280  9431 11397]
# 第 49 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 50 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99978   0.99942     13818
#            1    0.88000   0.62857   0.73333        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.93953   0.81418   0.86638     13853
# weighted avg    0.99876   0.99885   0.99875     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3989 4218 4930 5336 5507 6686 7051
#  7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 51 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 52 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99964   0.99935     13818
#            1    0.81481   0.62857   0.70968        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.90694   0.81410   0.85451     13853
# weighted avg    0.99859   0.99870   0.99862     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6666
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 53 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99964   0.99939     13818
#            1    0.82143   0.65714   0.73016        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.91028   0.82839   0.86477     13853
# weighted avg    0.99868   0.99877   0.99870     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930
#   5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762
#   8820  9280  9431 13022]
# 第 54 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 3651 3706 3989 4218 4930 5336 5507 6686 7051
#  7130 7275 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 55 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99964   0.99939     13818
#            1    0.82143   0.65714   0.73016        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.91028   0.82839   0.86477     13853
# weighted avg    0.99868   0.99877   0.99870     13853
#
# [   80   155  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930
#   5336  5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762
#   8820  9280  9431 12103]
# 第 56 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99971   0.99939     13818
#            1    0.84615   0.62857   0.72131        35
#
#    micro avg    0.99877   0.99877   0.99877     13853
#    macro avg    0.92261   0.81414   0.86035     13853
# weighted avg    0.99867   0.99877   0.99868     13853
#
# [  80 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507 6686
#  7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 57 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]
# 第 58 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99906   0.99964   0.99935     13818
#            1    0.81481   0.62857   0.70968        35
#
#    micro avg    0.99870   0.99870   0.99870     13853
#    macro avg    0.90694   0.81410   0.85451     13853
# weighted avg    0.99859   0.99870   0.99862     13853
#
# [   80  1869  1951  2439  2785  2977  3651  3706  3989  4218  4930  5336
#   5507  6686  7051  7130  7308  7537  7792  7906  8527  8728  8762  8820
#   9280  9431 12103]
# 第 59 個Model :
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853
#
# [  80  155 1869 1951 2439 2785 2977 3651 3706 3989 4218 4930 5336 5507
#  6686 7051 7130 7308 7537 7792 7906 8527 8728 8762 8820 9280 9431]

# %%
for threshold in range(1,len(dev)+1):
    devans=[0 for i in range(len(dev))]
    num = 0
    for i in range(len(devscore)):
        if(devscore[i]>threshold):
            devans[i]=1
            num+=1
        else : continue
    if(num==36):
        print(threshold)

# %%
devans=[0 for i in range(len(dev))]
for i in range(len(devscore)):
    if(devscore[i]>10):
        devans[i]=1
    else : continue

print(classification_report(val_labels,devans,digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99971   0.99942     13818
#            1    0.85185   0.65714   0.74194        35
#
#    micro avg    0.99885   0.99885   0.99885     13853
#    macro avg    0.92549   0.82843   0.87068     13853
# weighted avg    0.99876   0.99885   0.99877     13853

# %% [raw]
# 結論 : 2018選用能提升recall

# %% [raw]
# 原本
#               precision    recall  f1-score   support
#
#            0    0.99913   0.99978   0.99946     13818
#            1    0.88462   0.65714   0.75410        35
#
#     accuracy                        0.99892     13853
#    macro avg    0.94187   0.82846   0.87678     13853
# weighted avg    0.99884   0.99892   0.99884     13853
#
# 新 皆同個參數
#               precision    recall  f1-score   support
#
#            0    0.99942   0.99935   0.99938     13818
#            1    0.75000   0.77143   0.76056        35
#
#     accuracy                        0.99877     13853
#    macro avg    0.87471   0.88539   0.87997     13853
# weighted avg    0.99879   0.99877   0.99878     13853
